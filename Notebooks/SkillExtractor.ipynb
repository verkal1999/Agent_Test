# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS

AG = Namespace("http://www.semanticweb.org/AgentProgramParams/")
DP = Namespace("http://www.semanticweb.org/AgentProgramParams/dp_")

SKILL_CLASS = AG.class_Skill
P_HAS_SKILL_DESCRIPTION = DP.dp_hasSkillDescription

# === 1) Pfade hier setzen ===
KG_IN  = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl"          # oder None für "neuen Graph"
KG_OUT = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl"

# === 2) Skill-Liste hier einfügen ===
SKILLS = [
    # HRL – Hochregallager / Storage & Retrieval / RBG
    {
        "id": "Skill_HRL_RBG_MoveX",
        "label": "HRL: RBG X verfahren",
        "desc": "Verfährt den Regalbediengerät Schlitten entlang der X Achse zur horizontalen Positionierung im Hochregallager."
    },
    {
        "id": "Skill_HRL_RBG_MoveY",
        "label": "HRL: RBG Y verfahren",
        "desc": "Verfährt die Hubachse entlang der Y Achse zur vertikalen Positionierung im Hochregallager."
    },
    {
        "id": "Skill_HRL_RBG_MoveOutrigger",
        "label": "HRL: Ausleger verfahren",
        "desc": "Fährt den Ausleger des Regalbediengeräts ein oder aus, um Werkstücke aufzunehmen oder abzulegen."
    },
    {
        "id": "Skill_HRL_CB_DriveConveyor",
        "label": "HRL: Förderband antreiben",
        "desc": "Startet oder stoppt das Förderband der Ein und Auslagerungsstation zum Materialtransport zwischen Stationen."
    },
    {
        "id": "Skill_HRL_InternalSafety_Check",
        "label": "HRL: Sicherheitsprüfung",
        "desc": "Prüft sicherheitsrelevante Sensorik oder Zustände im Hochregallager Kontext, z. B. Endlagen oder Freigaben."
    },

    # SG1 – Vacuum Gripper Robot 1
    {
        "id": "Skill_SG1_MoveHorizontal",
        "label": "SG1: Horizontal verfahren",
        "desc": "Verfährt den Vakuum Greifer Roboter entlang der horizontalen Achse zur Positionierung über einem Zielpunkt."
    },
    {
        "id": "Skill_SG1_MoveVertical",
        "label": "SG1: Vertikal verfahren",
        "desc": "Verfährt den Vakuum Greifer Roboter entlang der vertikalen Achse zum Absenken oder Anheben des Greifers."
    },
    {
        "id": "Skill_SG1_Rotate",
        "label": "SG1: Rotieren",
        "desc": "Rotiert den Greifer oder die Werkzeugaufnahme zur Ausrichtung des Werkstücks."
    },
    {
        "id": "Skill_SG1_VacuumPickPlace",
        "label": "SG1: Ansaugen und Ablagen",
        "desc": "Aktiviert Vakuum zum Greifen eines Werkstücks und deaktiviert Vakuum zum Ablagevorgang."
    },

    # SG2
    {
        "id": "Skill_SG2_MoveHorizontal",
        "label": "SG2: Horizontal verfahren",
        "desc": "Verfährt den zweiten Vakuum Greifer entlang der horizontalen Achse zur Positionierung."
    },
    {
        "id": "Skill_SG2_MoveVertical",
        "label": "SG2: Vertikal verfahren",
        "desc": "Verfährt den zweiten Vakuum Greifer entlang der vertikalen Achse zum Greifen oder Lösen."
    },
    {
        "id": "Skill_SG2_Rotate",
        "label": "SG2: Rotieren",
        "desc": "Rotiert die Greiferaufnahme zur Ausrichtung des Werkstücks im Handhabungsprozess."
    },
    {
        "id": "Skill_SG2_VacuumPickPlace",
        "label": "SG2: Ansaugen und Ablagen",
        "desc": "Greifen und Ablegen über Vakuumfunktion am zweiten Greifer."
    },

    # SG3
    {
        "id": "Skill_SG3_MoveHorizontal",
        "label": "SG3: Horizontal verfahren",
        "desc": "Verfährt den dritten Vakuum Greifer entlang der horizontalen Achse zur Positionierung."
    },
    {
        "id": "Skill_SG3_MoveVertical",
        "label": "SG3: Vertikal verfahren",
        "desc": "Verfährt den dritten Vakuum Greifer entlang der vertikalen Achse zum Absenken oder Anheben."
    },
    {
        "id": "Skill_SG3_Rotate",
        "label": "SG3: Rotieren",
        "desc": "Rotiert die Greiferaufnahme zur Ausrichtung des Werkstücks am dritten Greifer."
    },
    {
        "id": "Skill_SG3_VacuumPickPlace",
        "label": "SG3: Ansaugen und Ablagen",
        "desc": "Greifen und Ablegen über Vakuumfunktion am dritten Greifer."
    },

    # SORT – Sorting Line with Color Detection
    {
        "id": "Skill_SORT_CB_DriveConveyor",
        "label": "SORT: Förderband antreiben",
        "desc": "Startet oder stoppt das Förderband der Sortierstrecke für den Transport durch die Farberkennung."
    },
    {
        "id": "Skill_SORT_Color_Detect",
        "label": "SORT: Farbe erkennen",
        "desc": "Ermittelt die Werkstückfarbe über Farbsensorik der Sortierstrecke (z. B. für anschließende Sortierlogik)."
    },
    {
        "id": "Skill_SORT_Pusher_Move",
        "label": "SORT: Schieber bewegen",
        "desc": "Bewegt den Ausschleuser oder Schieber zur Übergabe des Werkstücks in eine definierte Bahn oder Rutsche."
    },
    {
        "id": "Skill_SORT_Chute_BufferStatus",
        "label": "SORT: Pufferstatus Rutsche lesen",
        "desc": "Liest den Belegstatus einer Rutsche oder eines Puffers (z. B. frei oder belegt) über Sensorik."
    },
    {
        "id": "Skill_SORT_LightBarrier_Check",
        "label": "SORT: Lichtschranke prüfen",
        "desc": "Prüft Lichtschranken oder Durchlauf Sensorik zur Werkstückdetektion im Sortierbereich."
    },

    # MBS – Multi Processing Station with Oven
    {
        "id": "Skill_MBS_SuctionGripper_MoveHorizontal",
        "label": "MBS: Greifer horizontal verfahren",
        "desc": "Verfährt den Handhabungs Greifer der Multi Processing Station horizontal zur Positionierung an Stationen."
    },
    {
        "id": "Skill_MBS_SuctionGripper_MoveVertical",
        "label": "MBS: Greifer vertikal verfahren",
        "desc": "Verfährt den Handhabungs Greifer der Multi Processing Station vertikal zum Greifen oder Ablegen."
    },
    {
        "id": "Skill_MBS_Turntable_Rotate",
        "label": "MBS: Drehteller rotieren",
        "desc": "Rotiert den Drehteller zur Übergabe zwischen Bearbeitungsschritten oder zur Positionierung eines Werkstücks."
    },
    {
        "id": "Skill_MBS_PushingDevice_Move",
        "label": "MBS: Schiebevorrichtung bewegen",
        "desc": "Bewegt die Schiebevorrichtung zur Werkstückübergabe oder zum Einschub in die Ofenstation."
    },
    {
        "id": "Skill_MBS_Cutter_Cut",
        "label": "MBS: Schneiden",
        "desc": "Startet den Schneidprozess an der Schneidemaschine innerhalb der Multi Processing Station."
    },
    {
        "id": "Skill_MBS_Oven_ClampUnclamp",
        "label": "MBS: Werkstück spannen oder lösen",
        "desc": "Spann oder Lösevorgang am Werkstück in der Ofenstation zur sicheren Positionierung während der Bearbeitung."
    },
    {
        "id": "Skill_MBS_Oven_MoveInOut",
        "label": "MBS: Werkstück in Ofen ein oder ausfahren",
        "desc": "Führt den Einschub oder Ausschub des Werkstücks in die Ofenstation über eine Schiebeeinheit aus."
    },
    {
        "id": "Skill_MBS_Oven_Harden",
        "label": "MBS: Härten",
        "desc": "Startet den Härtprozess in der Ofenstation als Bearbeitungsschritt der Multi Processing Station."
    },
    {
        "id": "Skill_MBS_CB_DriveConveyor",
        "label": "MBS: Förderband antreiben",
        "desc": "Startet oder stoppt Förderbandbewegungen im Bereich der Multi Processing Station."
    },

    # CS1 – Conveyor & Punch 1
    {
        "id": "Skill_CS1_Conveyor_FeedToPunch",
        "label": "CS1: Zufördern zur Stanze",
        "desc": "Fördert ein Werkstück zur Stanzstation 1 und positioniert es für den Stanzvorgang."
    },
    {
        "id": "Skill_CS1_Conveyor_FeedFromPunch",
        "label": "CS1: Abfördern von der Stanze",
        "desc": "Fördert ein bearbeitetes Werkstück von der Stanzstation 1 ab und übergibt es an den nächsten Transportabschnitt."
    },
    {
        "id": "Skill_CS1_Punch_Punch",
        "label": "CS1: Stanzen",
        "desc": "Startet den Stanzvorgang an der Stanzstation 1."
    },

    # CS2 – Conveyor & Punch 2
    {
        "id": "Skill_CS2_Conveyor_FeedToPunch",
        "label": "CS2: Zufördern zur Stanze",
        "desc": "Fördert ein Werkstück zur Stanzstation 2 und positioniert es für den Stanzvorgang."
    },
    {
        "id": "Skill_CS2_Conveyor_FeedFromPunch",
        "label": "CS2: Abfördern von der Stanze",
        "desc": "Fördert ein bearbeitetes Werkstück von der Stanzstation 2 ab und übergibt es an den nächsten Transportabschnitt."
    },
    {
        "id": "Skill_CS2_Punch_Punch",
        "label": "CS2: Stanzen",
        "desc": "Startet den Stanzvorgang an der Stanzstation 2."
    },

    # USTR – U Straße / Transferstrecken / Bearbeitungsstationen
    {
        "id": "Skill_USTR_CB1_DriveConveyor",
        "label": "USTR: Förderband 1 antreiben",
        "desc": "Startet oder stoppt Förderband 1 zur Zuführung oder Übergabe in der U Straße."
    },
    {
        "id": "Skill_USTR_CB2_FeedIn",
        "label": "USTR: Förderband 2 zutransport",
        "desc": "Transportiert Werkstücke auf Förderband 2 in Richtung Bearbeitung."
    },
    {
        "id": "Skill_USTR_CB2_FeedOut",
        "label": "USTR: Förderband 2 abtransport",
        "desc": "Transportiert Werkstücke auf Förderband 2 aus dem Bearbeitungsbereich heraus."
    },
    {
        "id": "Skill_USTR_CB3_FeedIn",
        "label": "USTR: Förderband 3 zutransport",
        "desc": "Transportiert Werkstücke auf Förderband 3 in Richtung Bearbeitung."
    },
    {
        "id": "Skill_USTR_CB3_FeedOut",
        "label": "USTR: Förderband 3 abtransport",
        "desc": "Transportiert Werkstücke auf Förderband 3 aus dem Bearbeitungsbereich heraus."
    },
    {
        "id": "Skill_USTR_CB4_DriveConveyor",
        "label": "USTR: Förderband 4 antreiben",
        "desc": "Startet oder stoppt Förderband 4 zur Pufferung oder Übergabe in der U Straße."
    },
    {
        "id": "Skill_USTR_PD1_CornerTransfer",
        "label": "USTR: Ecktransport 1",
        "desc": "Ecktransport mittels Schiebeeinheit 1 zur Richtungsänderung oder Übergabe zwischen Förderstrecken."
    },
    {
        "id": "Skill_USTR_PD2_CornerTransfer",
        "label": "USTR: Ecktransport 2",
        "desc": "Ecktransport mittels Schiebeeinheit 2 zur Richtungsänderung oder Übergabe zwischen Förderstrecken."
    },
    {
        "id": "Skill_USTR_Drill_Drill",
        "label": "USTR: Bohren",
        "desc": "Startet den Bohrprozess als Bearbeitungsschritt in der U Straße Bearbeitungsstation."
    },
    {
        "id": "Skill_USTR_Mill_Mill",
        "label": "USTR: Fräsen",
        "desc": "Startet den Fräsprozess als Bearbeitungsschritt in der U Straße Bearbeitungsstation."
    },
    {
        "id": "Skill_USTR_CB4_BufferStatus",
        "label": "USTR: Pufferstatus lesen",
        "desc": "Liest den Belegstatus eines Pufferplatzes im Bereich Förderband 4, z. B. frei oder belegt."
    },
]

def add_skills(g: Graph) -> tuple[int, int]:
    g.bind("ag", AG)
    g.bind("dp", DP)
    g.bind("rdfs", RDFS)

    created = 0
    updated = 0

    for s in SKILLS:
        skill_uri = AG[s["id"]]

        existed = (skill_uri, RDF.type, SKILL_CLASS) in g

        g.add((skill_uri, RDF.type, SKILL_CLASS))
        g.set((skill_uri, RDFS.label, Literal(s["label"])))
        g.set((skill_uri, P_HAS_SKILL_DESCRIPTION, Literal(s["desc"])))

        if existed:
            updated += 1
        else:
            created += 1

    return created, updated

def delete_all_skills(g: Graph) -> int:
    skill_uris = set(g.subjects(RDF.type, SKILL_CLASS))
    for s in skill_uris:
        # entfernt Label, Description, rdf:type, alles was am Skill hängt
        g.remove((s, None, None))
    return len(skill_uris)



# === Graph laden (optional) ===
g = Graph()


if KG_IN:
    g.parse(KG_IN, format="turtle")   # Pfad ist hier! :contentReference[oaicite:1]{index=1}

deleted = delete_all_skills(g)
print("Gelöschte Skills:", deleted)

created, updated = add_skills(g)

# === Speichern ===
g.serialize(destination=KG_OUT, format="turtle")  # Pfad ist hier! :contentReference[oaicite:2]{index=2}

print(f"Fertig. Skills: {len(SKILLS)} (created={created}, updated={updated})")
print("Output:", KG_OUT)
# Out:
# Gelöschte Skills: 48
# Fertig. Skills: 48 (created=48, updated=0)
# Output: D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl

# %%
from rdflib import Graph, URIRef
from rdflib.namespace import RDF, RDFS
import re
import pandas as pd

KG_PATH = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl"  # <- ggf. auf deinen KG mit Skills ändern

g = Graph()
g.parse(KG_PATH, format="turtle")

AP = URIRef("http://www.semanticweb.org/AgentProgramParams/")  # nur für Anzeige
APNS = g.namespace_manager.store.namespace("ap")
if not APNS:
    g.bind("ap", "http://www.semanticweb.org/AgentProgramParams/")
APNS = "http://www.semanticweb.org/AgentProgramParams/"
ap = lambda local: URIRef(APNS + local)

ONLY_WITH_METHOD = True  # entspricht deinem bisherigen Filter

# --- POUs holen (wie in deinem Notebook, aber als DF) ---
Q_POUS = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX ap:  <http://www.semanticweb.org/AgentProgramParams/>

SELECT ?pou ?name ?lang ?code ?t
WHERE {
  # ?pou rdf:type ?t .
  FILTER(?t IN (ap:class_Program, ap:class_FBType)) .
  # ?pou ap:dp_hasPOUName ?name .
  # ?pou ap:dp_hasPOUCode ?code .
  OPTIONAL { ?pou ap:dp_hasPOULanguage ?lang . }
}
"""

pou_rows = []
for r in g.query(Q_POUS):
    code = str(r.code) if r.code else ""
    if ONLY_WITH_METHOD and "METHOD" not in code:
        continue
    pou_rows.append({
        "pou_iri": str(r.pou),
        "pou_name": str(r.name),
        "lang": str(r.lang) if r.lang else None,
        "type": str(r.t),
        "code": code
    })

df_pous = pd.DataFrame(pou_rows)
df_pous = df_pous[~df_pous["pou_name"].str.startswith("FB_", na=False)]
df_pous = df_pous[~df_pous["pou_name"].str.contains("Schablone", na=False)]
df_pous = df_pous[~df_pous["pou_name"].str.contains("JobMethode", na=False)]
print("POUs/Programme:", len(df_pous))
df_pous.head(3)
# Out:
# POUs/Programme: 20
#                                              pou_iri  \
# 2  http://www.semanticweb.org/AgentProgramParams/...
# 3  http://www.semanticweb.org/AgentProgramParams/...
# 4  http://www.semanticweb.org/AgentProgramParams/...
#
#                        pou_name lang  \
# 2      MBS_CB_AS_HorizontalMove   ST
# 3    MBS_DmPD_AS_HorizontalMove   ST
# 4  MBS_MR01_AS_HardeningProcess   ST
#
#                                                 type  \
# 2  http://www.semanticweb.org/AgentProgramParams/...
# 3  http://www.semanticweb.org/AgentProgramParams/...
# 4  http://www.semanticweb.org/AgentProgramParams/...
#
#                                                 code
# 2  // POU MBS_CB_AS_HorizontalMove body\nMBS_CB_H...
# 3  // POU MBS_DmPD_AS_HorizontalMove body\nMBS_Dm...
# 4  // POU MBS_MR01_AS_HardeningProcess body\nMBS_...

# %%
# --- Skills holen: class_Skill + Beschreibung (robust: ap:... und dp_:...) ---
Q_SKILLS = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX ap:  <http://www.semanticweb.org/AgentProgramParams/>
PREFIX dp:  <http://www.semanticweb.org/AgentProgramParams/dp_>

SELECT ?skill ?label ?desc1 ?desc2
WHERE {
  # ?skill rdf:type ap:class_Skill .
  OPTIONAL { ?skill rdfs:label ?label . }
  OPTIONAL { ?skill ap:dp_hasSkillDescription ?desc1 . }
  OPTIONAL { ?skill dp:dp_hasSkillDescription ?desc2 . }
}
"""

skill_rows = []
for r in g.query(Q_SKILLS):
    desc = ""
    if r.desc1:
        desc = str(r.desc1)
    elif r.desc2:
        desc = str(r.desc2)
    skill_rows.append({
        "skill_iri": str(r.skill),
        "label": str(r.label) if r.label else None,
        "desc": desc
    })

df_skills = pd.DataFrame(skill_rows)
print("Skills im KG:", len(df_skills))
df_skills.head(5)
# Out:
# Skills im KG: 48
#                                            skill_iri  \
# 0  http://www.semanticweb.org/AgentProgramParams/...
# 1  http://www.semanticweb.org/AgentProgramParams/...
# 2  http://www.semanticweb.org/AgentProgramParams/...
# 3  http://www.semanticweb.org/AgentProgramParams/...
# 4  http://www.semanticweb.org/AgentProgramParams/...
#
#                            label  \
# 0  CS1: Abfördern von der Stanze
# 1      CS1: Zufördern zur Stanze
# 2                   CS1: Stanzen
# 3                   CS2: Stanzen
# 4        HRL: Sicherheitsprüfung
#
#                                                 desc
# 0  Fördert ein bearbeitetes Werkstück von der Sta...
# 1  Fördert ein Werkstück zur Stanzstation 1 und p...
# 2    Startet den Stanzvorgang an der Stanzstation 1.
# 3    Startet den Stanzvorgang an der Stanzstation 2.
# 4  Prüft sicherheitsrelevante Sensorik oder Zustä...

# %%
from groq import Groq
import json
import time

api_key_path = r"C:\Users\Alexander Verkhov\Desktop\APIKey_Groq.txt"
with open(api_key_path, "r", encoding="utf-8") as f:
    groq_api_key = f.read().strip()

client = Groq(api_key=groq_api_key)

TASK_DEFINITION = """
Du bekommst IEC 61131-3 Structured Text Code eines POU/Programms aus einer SPS (fischertechnik I4.0 Demonstrator/Simulator Kontext).
Außerdem bekommst du einen Katalog an Skills (Name + Kurzbeschreibung).
Deine Aufgabe: schätze, welche Skills durch diesen POU implementiert werden.

Wichtig:
- Wähle NUR Skills aus der übergebenen Kandidatenliste.
- Wenn du unsicher bist: geringe confidence und kurz erklären.
- Liefere Evidence als kurze Code-Zeilen (wörtlich, 1 bis 4 Zeilen pro Evidence).
- Gib ausschließlich gültiges JSON zurück.
"""

# %%
# === Glossar für Abkürzungen / Prefixe in POU-Namen und Variablen ===
# Ziel: Das LLM versteht HRL/MBS/VSG/... statt "Buchstabensuppe".

ABBREVIATIONS = {
    "HRL": "Hochregallager (storage & retrieval / high-bay warehouse)",
    "RBG": "Regalbediengerät (gantry/warehouse robot)",
    "MBS": "Multi-Bearbeitungsstation (multi processing station, z. B. Ofen/Schneiden je nach Aufbau)",
    "VSG": "Vakuum-Sauggreifer (vacuum suction gripper / pick-and-place)",
    "SST": "Sortierstrecke / Sortierstation (sorting line/station)",
    "CS":  "Conveyor & Stanzmaschine (conveyor + punching station)",
    "CB":  "Conveyor Belt (Förderband)",
    "PD":  "Pushing Device (Schiebeeinheit/Transfer)",
    "MR01": "Bearbeitungsmodul 01 (im MBS-Kontext)",
    "MR02": "Bearbeitungsmodul 02 (im MBS-Kontext)",
    "AS":  "Atomic Skill (atomarer Skill, Skill-Implementierung als POU)",
}

SKILL_VERBS = {
    "HorizontalMove": "horizontale Bewegung/Transport",
    "VerticalMove": "vertikale Bewegung",
    "RotationMove": "Rotation/Drehbewegung",
    "SuctionProcess": "Vakuum greifen/halten/lösen",
    "HardeningProcess": "Härten/Ofenprozess",
    "CuttingProcess": "Schneiden",
    "CompressorControl": "Kompressor/Vakuum-Erzeugung steuern",
    "ColorDetection": "Farberkennung/Farbsensorik",
    "BufferStatus": "Pufferstatus/Belegstatus lesen",
}

GLOSSARY_TEXT = (
    "Glossary / Prefix legend for identifiers:\n"
    + json.dumps(
        {"abbreviations": ABBREVIATIONS, "skill_verbs": SKILL_VERBS},
        ensure_ascii=False,
        indent=2
    )
)

# Optional: kurz prüfen, ob typische Prefixe fehlen
print(GLOSSARY_TEXT[:1000])
# Out:
# Glossary / Prefix legend for identifiers:
# {
#   "abbreviations": {
#     "HRL": "Hochregallager (storage & retrieval / high-bay warehouse)",
#     "RBG": "Regalbediengerät (gantry/warehouse robot)",
#     "MBS": "Multi-Bearbeitungsstation (multi processing station, z. B. Ofen/Schneiden je nach Aufbau)",
#     "VSG": "Vakuum-Sauggreifer (vacuum suction gripper / pick-and-place)",
#     "SST": "Sortierstrecke / Sortierstation (sorting line/station)",
#     "CS": "Conveyor & Stanzmaschine (conveyor + punching station)",
#     "CB": "Conveyor Belt (Förderband)",
#     "PD": "Pushing Device (Schiebeeinheit/Transfer)",
#     "MR01": "Bearbeitungsmodul 01 (im MBS-Kontext)",
#     "MR02": "Bearbeitungsmodul 02 (im MBS-Kontext)",
#     "AS": "Atomic Skill (atomarer Skill, Skill-Implementierung als POU)"
#   },
#   "skill_verbs": {
#     "HorizontalMove": "horizontale Bewegung/Transport",
#     "VerticalMove": "vertikale Bewegung",
#     "RotationMove": "Rotation/Drehbewegung",
# ...

# %%
# === Auto-Check: Welche Prefixe kommen in POU-Namen vor? ===
import re

def extract_prefixes(names):
    prefixes = set()
    for n in names:
        if not isinstance(n, str):
            continue
        # Beispiel: "HRL_RGB_AS_HorizontalMoveEncoders" -> HRL, RGB, AS
        parts = n.split("_")
        for p in parts[:4]:  # nimm nur die ersten Segmente
            if p and p.isupper() and len(p) <= 6:
                prefixes.add(p)
            # MR01/MR02 sind nicht vollständig uppercase, daher extra:
            if re.fullmatch(r"MR\d{2}", p):
                prefixes.add(p)
    return prefixes

pou_prefixes = extract_prefixes(df_pous["pou_name"].tolist())
skill_prefixes = extract_prefixes([str(x) for x in df_skills["label"].fillna("").tolist()])

all_prefixes = sorted(pou_prefixes | skill_prefixes)
missing = [p for p in all_prefixes if p not in ABBREVIATIONS]

print("Gefundene Prefixe:", all_prefixes)
print("Fehlen im Glossar:", missing)
# Out:
# Gefundene Prefixe: ['AS', 'CB', 'CS', 'HRL', 'MBS', 'MR01', 'MR02', 'PD', 'RGB', 'SST', 'VSG']
# Fehlen im Glossar: ['RGB']

# %%
token_re = re.compile(r"[A-Za-z_][A-Za-z0-9_]*")

def norm_tokens(text: str):
    return set(t.lower() for t in token_re.findall(text or ""))

def _station_from_pou_name(pou_name: str) -> str:
    if not pou_name:
        return ""
    return pou_name.split("_")[0].strip()

def _station_from_skill_label(label: str) -> str:
    # Skill-Label wie "HRL: ..." oder "MBS: ..."
    if not label or ":" not in label:
        return ""
    return label.split(":")[0].strip()

# Mini-Alias-Bridge (ohne Glossar erweitern)
ALIASES = {
    "hardeningprocess": ["härten", "ofen", "hardening", "heat"],
    "cuttingprocess": ["schneiden", "cutting", "cutter"],
    "colordetection": ["farbe", "farberkennung", "color"],
    "compressorcontrol": ["kompressor", "vakuum", "compressor"],
    "horizontalmove": ["horizontal", "verfahren", "move"],
    "verticalmove": ["vertikal", "vertical", "heben", "senken"],
    "rotationmove": ["rotieren", "rotation", "drehen"],
    "suctionprocess": ["vakuum", "ansaugen", "suction", "pick"],
}

def _augment_skill_text(label: str, desc: str) -> str:
    base = f"{label or ''} {desc or ''}".lower()
    aug = base
    for k, syns in ALIASES.items():
        if k in base:
            aug += " " + " ".join(syns)
    return aug

def pick_candidates_for_code(pou_name: str, code: str, df_skills: pd.DataFrame, top_n: int = 12):
    code_toks = norm_tokens(code)
    pou_station = _station_from_pou_name(pou_name)

    scored = []
    for _, s in df_skills.iterrows():
        label = s.get("label","") or ""
        desc  = s.get("desc","") or ""

        skill_station = _station_from_skill_label(label)
        txt = _augment_skill_text(label, desc)
        stoks = norm_tokens(txt)

        token_score = len(code_toks & stoks) / max(1, len(stoks))
        station_bonus = 0.25 if (pou_station and skill_station and pou_station == skill_station) else 0.0
        score = token_score + station_bonus
        scored.append((score, s))

    scored.sort(key=lambda x: x[0], reverse=True)
    picked = [s for sc, s in scored if sc > 0][:top_n]
    if not picked:
        picked = [s for _, s in scored[:top_n]]
    return pd.DataFrame(picked)


# Quick test:
if len(df_pous) and len(df_skills):
    cand = pick_candidates_for_code(
        df_pous.iloc[0]["pou_name"],
        df_pous.iloc[0]["code"],
        df_skills,
        top_n=12
    )
    cand[["label", "desc"]].head(5)

# %%
EXPECTED_KEYS_REQUIRED = ["pou_name", "matches"]   # notes ist optional!

MATCH_KEYS_REQUIRED = ["skill_iri", "confidence", "reason_short", "evidence"]  # skill_label optional

def infer_skill_implementations(pou_row: dict, candidate_skills_df: pd.DataFrame, model: str = "llama-3.1-8b-instant"):
    code = pou_row["code"] or ""

    # Kandidaten kompakt serialisieren
    cand_list = []
    iri_to_label = {}
    for _, s in candidate_skills_df.iterrows():
        iri = s["skill_iri"]
        label = s["label"] or iri.split("/")[-1]
        iri_to_label[iri] = label
        cand_list.append({
            "skill_iri": iri,
            "skill_label": label,
            "skill_description": s["desc"] or ""
        })

    allowed_skill_iris = [c["skill_iri"] for c in cand_list]

    prompt = f"""
{TASK_DEFINITION}


{GLOSSARY_TEXT}
Gib ausschließlich EIN JSON-Objekt zurück (kein Markdown, kein Text außenrum).

Du MUSST dieses JSON Schema einhalten:
{{
  "pou_name": "...",
  "matches": [
    {{
      "skill_iri": "<muss exakt einer aus allowed_skill_iris sein>",
      "skill_label": "<optional, wenn gesetzt dann aus Kandidatenliste übernehmen>",
      "confidence": 0.0,
      "reason_short": "...",
      "evidence": ["1-6 kurze Codezeilen wörtlich"]
    }}
  ],
  "notes": ""
}}

Regeln:
- Wähle NUR skill_iri Werte aus allowed_skill_iris.
- Nutze das Glossar, um Prefixe aus POU-Namen, Variablen und FB-Instanzen zu interpretieren (z. B. HRL_..., MBS_..., VSG_...).
- Wenn ein Prefix nicht im Glossar steht, erwähne das in notes und senke confidence.
- Wenn nichts passt, gib matches als [] zurück.
- notes soll IMMER existieren (wenn nichts: leerer String).

POU-Name: {pou_row["pou_name"]}
Sprache: {pou_row.get("lang")}

allowed_skill_iris:
{json.dumps(allowed_skill_iris, ensure_ascii=False)}

Skill-Kandidaten (nur diese wählen):
{json.dumps(cand_list, ensure_ascii=False, indent=2)}

Code:
{code}
""".strip()

    resp = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "Return valid JSON only. Do not add any extra text."},
            {"role": "user", "content": prompt},
        ],
        temperature=0.0,
        max_completion_tokens=900,
        response_format={"type": "json_object"},
    )

    data = json.loads(resp.choices[0].message.content)

    # --- Minimal validation (notes optional) ---
    missing = [k for k in EXPECTED_KEYS_REQUIRED if k not in data]
    if missing:
        raise ValueError(f"Missing keys in JSON: {missing}")

    # normalize notes
    if "notes" not in data or data["notes"] is None:
        data["notes"] = ""

    # normalize matches
    if not isinstance(data.get("matches"), list):
        data["matches"] = []

    # --- Validate + HARD FILTER matches against allowed IRIs ---
    filtered = []
    dropped = []
    for m in data["matches"]:
        # required keys in match
        m_missing = [k for k in MATCH_KEYS_REQUIRED if k not in m]
        if m_missing:
            dropped.append({"reason": f"missing_match_keys:{m_missing}", "match": m})
            continue

        iri = m["skill_iri"]
        if iri not in allowed_skill_iris:
            dropped.append({"reason": "skill_iri_not_allowed", "match": m})
            continue

        # coerce types
        try:
            m["confidence"] = float(m["confidence"])
        except:
            m["confidence"] = 0.0

        if not isinstance(m.get("evidence"), list):
            m["evidence"] = []

        # fix/force label from candidate list to avoid hallucinated labels
        m["skill_label"] = iri_to_label.get(iri, m.get("skill_label", iri.split("/")[-1]))

        filtered.append(m)

    if dropped:
        data["notes"] = (data["notes"] + f" | Dropped {len(dropped)} invalid matches").strip(" |")

    data["matches"] = filtered
    return data

# %%
# === ZELLE 8: Cleanup (alte LLM-Ergebnisse) + LLM-Loop + Schreiben in den KG ===

from rdflib.namespace import RDF, XSD
from rdflib import URIRef, Literal
from datetime import datetime, timezone
import hashlib, time

# ----------------------------
# 0) Cleanup: alte Hypothesen + implementsSkill entfernen
# ----------------------------
HYP_CLASS    = ap("class_SkillImplementationHypothesis")

P_ABOUT_POU  = ap("op_hasHypothesisAboutPOU")
P_ABOUT_SKILL= ap("op_hasHypothesisAboutSkill")
P_MODEL      = ap("dp_inferredByModel")

P_IMPL       = ap("op_implementsSkill")

# robust: sammle auch "kaputte" Hypothesen ohne rdf:type
old_claims = set()
old_claims |= set(g.subjects(RDF.type, HYP_CLASS))
old_claims |= set(g.subjects(P_ABOUT_POU, None))
old_claims |= set(g.subjects(P_ABOUT_SKILL, None))
old_claims |= set(g.subjects(P_MODEL, None))

for c in old_claims:
    g.remove((c, None, None))
    g.remove((None, None, c))

# Shortcut-Kanten entfernen
g.remove((None, P_IMPL, None))

print(f"Cleanup: {len(old_claims)} Hypothesen-Knoten gelöscht + op_implementsSkill Kanten entfernt")

# ----------------------------
# 1) KG-Writer Helpers (nutzt deine Properties)
# ----------------------------
CLASS_HYP = ap("class_SkillImplementationHypothesis")

P_CONF   = ap("dp_hasConfidence")
P_REASON = ap("dp_hasRationale")
P_EVID   = ap("dp_hasEvidenceSnippet")
P_TIME   = ap("dp_inferredAt")

def hyp_uri(pou_iri: str, skill_iri: str, model: str) -> URIRef:
    h = hashlib.sha1(f"{pou_iri}|{skill_iri}|{model}".encode("utf-8")).hexdigest()[:12]
    return URIRef(APNS + f"SkillImplHyp_{h}")

def write_mapping_to_kg(pou_iri: str, mapping_json: dict, model: str):
    pou_uri = URIRef(pou_iri)
    now = datetime.now(timezone.utc).isoformat()

    for m in (mapping_json.get("matches") or []):
        # optional: Confidence-Schwelle setzen
        # if float(m.get("confidence", 0.0)) < 0.35:
        #     continue

        skill_uri = URIRef(m["skill_iri"])
        claim = hyp_uri(pou_iri, m["skill_iri"], model)

        # claim überschreiben (id stabil)
        g.remove((claim, None, None))

        g.add((claim, RDF.type, CLASS_HYP))
        g.add((claim, P_ABOUT_POU, pou_uri))
        g.add((claim, P_ABOUT_SKILL, skill_uri))
        g.add((claim, P_CONF, Literal(float(m.get("confidence", 0.0)), datatype=XSD.decimal)))
        g.add((claim, P_REASON, Literal(m.get("reason_short", ""))))
        g.add((claim, P_MODEL, Literal(model)))
        g.add((claim, P_TIME, Literal(now, datatype=XSD.dateTime)))

        for ev in (m.get("evidence") or [])[:6]:
            g.add((claim, P_EVID, Literal(ev)))

        # Shortcut: POU implements Skill
        g.add((pou_uri, P_IMPL, skill_uri))

# ----------------------------
# 2) LLM-Loop
# ----------------------------
MODEL_NAME = "llama-3.1-8b-instant"
MAX_POUS = 20

results = []

for idx, row in df_pous.head(MAX_POUS).iterrows():
    try:
        # Kandidaten (stationsbewusst, falls du die neue Funktion nutzt)
        candidates_df = pick_candidates_for_code(row["pou_name"], row["code"], df_skills, top_n=12)

        out = infer_skill_implementations(row.to_dict(), candidates_df, model=MODEL_NAME)

        out["_pou_iri"] = row["pou_iri"]
        results.append(out)

        write_mapping_to_kg(row["pou_iri"], out, model=MODEL_NAME)

        print(f"[{len(results)}/{min(MAX_POUS, len(df_pous))}] {row['pou_name']} -> matches={len(out.get('matches', []))}")
        time.sleep(0.2)

    except Exception as e:
        print(f"[{idx}] ERROR bei {row['pou_name']}: {e}")

print("Fertig. Ergebnisse:", len(results))
# Out:
# Cleanup: 26 Hypothesen-Knoten gelöscht + op_implementsSkill Kanten entfernt
# [1/20] MBS_CB_AS_HorizontalMove -> matches=1
# [2/20] MBS_DmPD_AS_HorizontalMove -> matches=1
# [3/20] MBS_MR01_AS_HardeningProcess -> matches=1
# [4/20] MBS_MR02_AS_CuttingProcess -> matches=1
# [5/20] MBS_VSG_AS_VerticalMove -> matches=1
# [6/20] SST_CS_AS_ColorDetection -> matches=1
# [7/20] VSG_AS_CompressorControl -> matches=1
# [8/20] HRL_RGB_AS_VerticalMoveEncoders -> matches=1
# [9/20] MBS_VSG_AS_HorizontalMove -> matches=1
# [10/20] VSG_AS_HorizontalMoveEncoder -> matches=1
# [11/20] VSG_AS_RotationMoveEncoder -> matches=1
# [12/20] VSG_AS_VerticalMoveEncoder -> matches=1
# [13/20] HRL_CB_AS_HorizontalMoveSensors -> matches=3
# [14/20] HRL_RGB_AS_HorizontalMoveEncoders -> matches=2
# [15/20] HRL_RGB_AS_HorizontalMoveSensors -> matches=2
# [16/20] MBS_MR01_AS_HorizontalMoveSensors -> matches=2
# [17/20] MBS_VSG_AS_SuctionProcess -> matches=2
# [18/20] SST_PD_AS_HorizontalMove -> matches=1
# ...

# %%
KG_OUT = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl"
g.serialize(KG_OUT, format="turtle")
KG_OUT
# Out:
# 'D:\\MA_Python_Agent\\MSRGuard_Anpassung\\KGs\\Test2_filled.ttl'

# %%
import pandas as pd

HYP_CLASS = ap("class_SkillImplementationHypothesis")
P_ABOUT_POU = ap("op_hasHypothesisAboutPOU")
P_ABOUT_SKILL = ap("op_hasHypothesisAboutSkill")
P_CONF = ap("dp_hasConfidence")

def get_pou_name(pou_uri):
    return next((str(o) for o in g.objects(pou_uri, ap("dp_hasPOUName"))), "")

def get_skill_label(skill_uri):
    return next((str(o) for o in g.objects(skill_uri, RDFS.label)), "")

rows = []
for claim in g.subjects(RDF.type, HYP_CLASS):
    pou = next(g.objects(claim, P_ABOUT_POU), None)
    sk  = next(g.objects(claim, P_ABOUT_SKILL), None)
    conf = next(g.objects(claim, P_CONF), None)
    rows.append({
        "pou": get_pou_name(pou),
        "skill": get_skill_label(sk) if sk else "",
        "conf": float(conf) if conf else None
    })

df = pd.DataFrame(rows).sort_values(["conf"], ascending=False)
df.head(30)
# Out:
#                                   pou                              skill  conf
# 3          MBS_MR02_AS_CuttingProcess                     MBS: Schneiden   0.9
# 2        MBS_MR01_AS_HardeningProcess                        MBS: Härten   0.9
# 8           MBS_VSG_AS_HorizontalMove  MBS: Greifer horizontal verfahren   0.9
# 25           MBS_DmPD_AS_RotationMove           MBS: Drehteller rotieren   0.9
# 1          MBS_DmPD_AS_HorizontalMove  MBS: Greifer horizontal verfahren   0.8
# 0            MBS_CB_AS_HorizontalMove          MBS: Förderband antreiben   0.8
# 5            SST_CS_AS_ColorDetection      CS1: Abfördern von der Stanze   0.8
# 6            VSG_AS_CompressorControl            SG1: Vertikal verfahren   0.8
# 7     HRL_RGB_AS_VerticalMoveEncoders               HRL: RBG Y verfahren   0.8
# 4             MBS_VSG_AS_VerticalMove    MBS: Greifer vertikal verfahren   0.8
# 9        VSG_AS_HorizontalMoveEncoder          SG1: Horizontal verfahren   0.8
# ...
