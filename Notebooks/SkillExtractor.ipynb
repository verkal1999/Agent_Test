# %%
from rdflib import Graph, URIRef, RDF

KG_PATH = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test2_filled.ttl"
g = Graph()
g.parse(KG_PATH, format="turtle")

Q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX ap:  <http://www.semanticweb.org/AgentProgramParams/>

SELECT ?pou ?name ?lang ?code
WHERE {
  # ?pou rdf:type ?t .
  FILTER(?t IN (ap:class_Program, ap:class_FBType)) .
  # ?pou ap:dp_hasPOUName ?name .
  # ?pou ap:dp_hasPOUCode ?code .
  FILTER(CONTAINS(STR(?code), "METHOD")) .
  OPTIONAL { ?pou ap:dp_hasPOULanguage ?lang . }
}
"""
rows = []
for r in g.query(Q):
    rows.append({
        "pou_iri": str(r.pou),
        "name": str(r.name),
        "lang": str(r.lang) if r.lang else None,
        "code": str(r.code) if r.code else None,
    })
    print(str(r.pou), str(r.name), str(r.lang) if r.lang else None, str(r.code) if r.code else None)

print("POUs:", len(rows))
print([x["name"] for x in rows[:5]])
# Out:
# http://www.semanticweb.org/AgentProgramParams/FBType_FB_MyOpcUaMethod FB_MyOpcUaMethod ST // METHOD Multiply of FB_MyOpcUaMethod
# Multiply := a * b;
# http://www.semanticweb.org/AgentProgramParams/FBType_JobMethode_Schablone JobMethode_Schablone ST // POU JobMethode_Schablone body
# JobMethode_Name(
#     MethodCall := MethodCall_Name,
#     NotAus_Signal := NotAusSignal,
#     Direction_01 := Direction_01,
#     Direction_02 := Direction_02,
#     LightSensor_01 := LightSensor_01,
#     LightSensor_02 := LightSensor_02,
#     TS_Endschalter_01 := TS_Endschalter_01,
#     AutomaticMode := _REFACTOR_,
#     TS_Endschalter_02 := TS_Endschalter_02,
#     TS_EndschalterEntlastung := TS_EndschalterEntlastung,
#     TOF_Time_Motoransteuerung := TOF_Time_Motoransteuerung,
#     TOF_Time_EndschalterEntlastung := TOF_Time_EndschalterEntlastung
# );
# Motor_Ansteuerung01 := JobMethode_Name.Motor_Direction01;
#
# // METHOD Abort of JobMethode_Schablone
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of JobMethode_Schablone
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetCall;
# 	MethodCall := MethodCall_Name;
# END_IF
#
# // METHOD Start of JobMethode_Schablone
# callCounterStart := callCounterStart + 1;
#
# MethodCall_Name := MethodCall;
# DirectionPointA := Direction_01;
# DirectionPointB := Direction_02;
# EndschalterEntlastung := EndschalterEntlastung;
#
# IF DirectionPointA := TRUE THEN
# 	DirectionPointB := FALSE;
# END_IF
#
# IF DirectionPointB := TRUE THEN
# 	DirectionPointA := FALSE;
# END_IF
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_CB_AS_HorizontalMove MBS_CB_AS_HorizontalMove ST // POU MBS_CB_AS_HorizontalMove body
# MBS_CB_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := LightSensor_01,
#     TouchSensorRelief := ,
#     TOF_Time_MotorControl := TOF_Time_MotorControl,
#     TOF_Time_TouchSensorRelief := ,
#     OperatingMode := AutomaticMode
# );
# DO_MovingHorizontalCB_01 := MBS_CB_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_CB_AS_HorizontalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_CB_AS_HorizontalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of MBS_CB_AS_HorizontalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := DirectionPoint;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_DmPD_AS_HorizontalMove MBS_DmPD_AS_HorizontalMove ST // POU MBS_DmPD_AS_HorizontalMove body
# MBS_DmPD_VerticalMove(
#     MethodCall := MethodCall_CompressorControl,
#     EmergencyStopSignal := ESS,
#     Destination := DestinationVertical,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := ,
#     DI03_EncoderStart01 := ,
#     DI04_EncoderStart02 := ,
#     DI05_EncoderStart03 := ,
#     DI06_EncoderStart04 := ,
#     DI07_EncoderStart05 := ,
#     DI08_EncoderStart06 := ,
#     DI09_EncoderTarget01 := ,
#     DI10_EncoderTarget02 := ,
#     DI11_EncoderTarget03 := ,
#     DI12_EncoderTarget04 := ,
#     DI13_EncoderTarget05 := ,
#     DI14_EncoderTarget06 := ,
#     PowerOFF_SelfSet := PowerOFF_SelfSet,
#     TON_Time_PowerOFFSelfSet := PowerOFFDelay_SelfSet,
#     TON_Time_Compressor := TON_PowerOnDelay_Compressor,
#     TON_Time_Valve := TON_PowerOnDelay_Valve,
#     OperatingMode := AutomaticMode
# );
# DO_ControlCompressorDmPD_01 := MBS_DmPD_VerticalMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_DmPD_AS_HorizontalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_DmPD_AS_HorizontalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CompressorControl;
# END_IF
#
# // METHOD Start of MBS_DmPD_AS_HorizontalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CompressorControl := MethodCall;
# DestinationVertical := DestinationPoint;
# PowerOFF_SelfSet := SelfSetPowerOff;
# PowerOFFDelay_SelfSet := SelfSetPowerOffDelay;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_MR01_AS_HardeningProcess MBS_MR01_AS_HardeningProcess ST // POU MBS_MR01_AS_HardeningProcess body
# MBS_MR01_HardeningProcess(
#     MethodCall := MethodCall_HardeningProcess,
#     EmergencyStopSignal := ESS,
#     InitStateDrive_Input := ,
#     DI01 := LightSensor_01,
#     TOF_Time_HardeningTime := ProcessingTime_HardeningProcess,
#     OperatingMode := AutomaticMode
# );
# DO_HardeningProcessControlMR01 := MBS_MR01_HardeningProcess.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_MR01_AS_HardeningProcess
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_MR01_AS_HardeningProcess
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HardeningProcess;
# END_IF
#
# // METHOD Start of MBS_MR01_AS_HardeningProcess
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HardeningProcess := MethodCall;
# ProcessingTime_HardeningProcess := ProcessingTime;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_MR02_AS_CuttingProcess MBS_MR02_AS_CuttingProcess ST // POU MBS_MR02_AS_CuttingProcess body
# MBS_MR02_CuttingProcess(
#     MethodCall := MethodCall_CuttingProcess,
#     EmergencyStopSignal := ESS,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     TOF_Time_CuttingTime := ProcessingTime_CuttingProcess,
#     OperatingMode := AutomaticMode
# );
# DO_CuttingProcessControlMR02 := MBS_MR02_CuttingProcess.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_MR02_AS_CuttingProcess
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_MR02_AS_CuttingProcess
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CuttingProcess;
# END_IF
#
# // METHOD Start of MBS_MR02_AS_CuttingProcess
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CuttingProcess := MethodCall;
# ProcessingTime_CuttingProcess := ProcessingTime;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_VSG_AS_VerticalMove MBS_VSG_AS_VerticalMove ST // POU MBS_VSG_AS_VerticalMove body
# MBS_VSG_VerticalMove(
#     MethodCall := MethodCall_CompressorControl,
#     EmergencyStopSignal := ESS,
#     Destination := DestinationVertical,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := ,
#     DI03_EncoderStart01 := ,
#     DI04_EncoderStart02 := ,
#     DI05_EncoderStart03 := ,
#     DI06_EncoderStart04 := ,
#     DI07_EncoderStart05 := ,
#     DI08_EncoderStart06 := ,
#     DI09_EncoderTarget01 := ,
#     DI10_EncoderTarget02 := ,
#     DI11_EncoderTarget03 := ,
#     DI12_EncoderTarget04 := ,
#     DI13_EncoderTarget05 := ,
#     DI14_EncoderTarget06 := ,
#     PowerOFF_SelfSet := PowerOFF_SelfSet,
#     TON_Time_PowerOFFSelfSet := PowerOFFDelay_SelfSet,
#     TON_Time_Compressor := TON_PowerOnDelay_Compressor,
#     TON_Time_Valve := TON_PowerOnDelay_Valve,
#     OperatingMode := AutomaticMode
# );
# DO_ControlCompressorVerticalMoveVSG_01 := MBS_VSG_VerticalMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_VSG_AS_VerticalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_VSG_AS_VerticalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CompressorControl;
# END_IF
#
# // METHOD Start of MBS_VSG_AS_VerticalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CompressorControl := MethodCall;
# DestinationVertical := DestinationPoint;
# PowerOFF_SelfSet := SelfSetPowerOff;
# PowerOFFDelay_SelfSet := SelfSetPowerOffDelay;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_SST_CS_AS_ColorDetection SST_CS_AS_ColorDetection ST // POU SST_CS_AS_ColorDetection body
# SST_Auto_ColorDetection(ColorSensor := Color_Sensor, ColorCode_1 := ColorCode1, ColorCode_2 := ColorCode2, ColorCode_3 := ColorCode3);
# Color_White := SST_Auto_ColorDetection.Color_1;
#
# // METHOD Abort of SST_CS_AS_ColorDetection
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of SST_CS_AS_ColorDetection
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetCall;
# 	MethodCall := MethodCall_ColorDetection;
# END_IF
#
# // METHOD Start of SST_CS_AS_ColorDetection
# callCounterStart := callCounterStart + 1;
#
# MethodCall_ColorDetection := MethodCall;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_VSG_AS_CompressorControl VSG_AS_CompressorControl ST // POU VSG_AS_CompressorControl body
# MBS_VSG_VerticalMove(
#     MethodCall := MethodCall_CompressorControl,
#     EmergencyStopSignal := ESS,
#     Destination := Destination,
#     InitStateDrive_Input := ,
#     DI01 := ,
#     DI02 := ,
#     DI03_EncoderStart01 := EncoderStartPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderStart03 := EncoderStartPosition03,
#     DI06_EncoderStart04 := EncoderStartPosition04,
#     DI07_EncoderStart05 := EncoderStartPosition05,
#     DI08_EncoderStart06 := EncoderStartPosition06,
#     DI09_EncoderTarget01 := EncoderTargetPosition01,
#     DI10_EncoderTarget02 := EncoderTargetPosition02,
#     DI11_EncoderTarget03 := EncoderTargetPosition03,
#     DI12_EncoderTarget04 := EncoderTargetPosition04,
#     DI13_EncoderTarget05 := EncoderTargetPosition05,
#     DI14_EncoderTarget06 := EncoderTargetPosition06,
#     PowerOFF_SelfSet := ,
#     TON_Time_PowerOFFSelfSet := ,
#     TON_Time_Compressor := TON_TimeCompressor,
#     TON_Time_Valve := TON_TimeValve,
#     OperatingMode := AutomaticMode
# );
# DO_CompressorVSG := MBS_VSG_VerticalMove.DigitalOutputControl_01;
#
# // METHOD Abort of VSG_AS_CompressorControl
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of VSG_AS_CompressorControl
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CompressorControl;
# END_IF
#
# // METHOD Start of VSG_AS_CompressorControl
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CompressorControl := MethodCall;
# Destination := Destination;
#
# EncoderTargetPosition_01 := EncoderTargetPosition01;
# EncoderTargetPosition_02 := EncoderTargetPosition02;
# EncoderTargetPosition_03 := EncoderTargetPosition03;
# EncoderTargetPosition_04 := EncoderTargetPosition04;
# EncoderTargetPosition_05 := EncoderTargetPosition05;
# EncoderTargetPosition_06 := EncoderTargetPosition06;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_HRL_CB_AS_HorizontalMoveSensors HRL_CB_AS_HorizontalMoveSensors ST // POU HRL_CB_AS_HorizontalMoveSensors body
# HRL_CB_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := LightBarrierSensor_01,
#     DI02 := LightBarrierSensor_02,
#     TouchSensorRelief := ,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := ,
#     OperatingMode := AutomaticMode
# );
# DO_MovingConveyorBelt := HRL_CB_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of HRL_CB_AS_HorizontalMoveSensors
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of HRL_CB_AS_HorizontalMoveSensors
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of HRL_CB_AS_HorizontalMoveSensors
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := MovementDirection;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_HRL_RGB_AS_HorizontalMoveEncoders HRL_RGB_AS_HorizontalMoveEncoders ST // POU HRL_RGB_AS_HorizontalMoveEncoders body
# HRL_RGB_HorizontalMoveWithEncoder(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02_EncoderStart01 := EncoderStartPosition01,
#     DI03_EncoderTarget01 := EncoderTargetPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderTarget02 := EncoderTargetPosition02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingHorizontalRGB_01 := HRL_RGB_HorizontalMoveWithEncoder.DigitalOutputControl_01;
#
# // METHOD Abort of HRL_RGB_AS_HorizontalMoveEncoders
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of HRL_RGB_AS_HorizontalMoveEncoders
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of HRL_RGB_AS_HorizontalMoveEncoders
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := MovementDirection;
# EncoderTargetPosition01 := EncoderPositionHorizontal_01;
# EncoderTargetPosition02 := EncoderPositionHorizontal_02;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_HRL_RGB_AS_HorizontalMoveSensors HRL_RGB_AS_HorizontalMoveSensors ST // POU HRL_RGB_AS_HorizontalMoveSensors body
# HRL_RGB_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02 := TouchSensor02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingHorizontalRGB_01 := HRL_RGB_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of HRL_RGB_AS_HorizontalMoveSensors
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of HRL_RGB_AS_HorizontalMoveSensors
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of HRL_RGB_AS_HorizontalMoveSensors
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# MovementDirection := DirectionHorizontal;
# TouchSensorRelief := TSR;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_HRL_RGB_AS_VerticalMoveEncoders HRL_RGB_AS_VerticalMoveEncoders ST // POU HRL_RGB_AS_VerticalMoveEncoders body
# HRL_RGB_VerticalMoveWithEncoder(
#     MethodCall := MethodCall_VerticalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionVertical,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02_EncoderStart01 := EncoderStartPosition01,
#     DI03_EncoderTarget01 := EncoderTargetPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderTarget02 := EncoderTargetPosition02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_TSR_TIME,
#     OperatingMode := AutomaticMode
# );
# DO_MovingVerticalRGB_01 := HRL_RGB_VerticalMoveWithEncoder.DigitalOutputControl_01;
#
# // METHOD Abort of HRL_RGB_AS_VerticalMoveEncoders
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of HRL_RGB_AS_VerticalMoveEncoders
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_VerticalMove;
# END_IF
#
# // METHOD Start of HRL_RGB_AS_VerticalMoveEncoders
# callCounterStart := callCounterStart + 1;
#
# MethodCall_VerticalMove := MethodCall;
# DirectionVertical := MovementDirection;
# EncoderTargetPosition01 := EncoderPositionVertical_01;
# EncoderTargetPosition02 := EncoderPositionVertical_02;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_MR01_AS_HorizontalMoveSensors MBS_MR01_AS_HorizontalMoveSensors ST // POU MBS_MR01_AS_HorizontalMoveSensors body
# MBS_MR01_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := TouchSensor_02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingHorizontalMR01_01 := MBS_MR01_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_MR01_AS_HorizontalMoveSensors
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_MR01_AS_HorizontalMoveSensors
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of MBS_MR01_AS_HorizontalMoveSensors
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HardeningProcess := MethodCall;
# ProcessingTime_HardeningProcess := ProcessingTime;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_VSG_AS_HorizontalMove MBS_VSG_AS_HorizontalMove ST // POU MBS_VSG_AS_HorizontalMove body
# MBS_VSG_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := TouchSensor_02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticeMode
# );
# DO_HorizontalMoveVSG_01 := MBS_VSG_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_VSG_AS_HorizontalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_VSG_AS_HorizontalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of MBS_VSG_AS_HorizontalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := DirectionPoint;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_VSG_AS_SuctionProcess MBS_VSG_AS_SuctionProcess ST // POU MBS_VSG_AS_SuctionProcess body
# MBS_VSG_SuctionProcess(
#     MethodCall := MethodCall_CompressorControl,
#     EmergencyStopSignal := ESS,
#     Destination := Destination,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := TouchSensor_02,
#     DI03_EncoderStart01 := ,
#     DI04_EncoderStart02 := ,
#     DI05_EncoderStart03 := ,
#     DI06_EncoderStart04 := ,
#     DI07_EncoderStart05 := ,
#     DI08_EncoderStart06 := ,
#     DI09_EncoderTarget01 := ,
#     DI10_EncoderTarget02 := ,
#     DI11_EncoderTarget03 := ,
#     DI12_EncoderTarget04 := ,
#     DI13_EncoderTarget05 := ,
#     DI14_EncoderTarget06 := ,
#     PowerOFF_SelfSet := ,
#     TON_Time_PowerOFFSelfSet := ,
#     TON_Time_Compressor := TON_PowerOnDelay_Compressor,
#     TON_Time_Valve := TON_PowerOnDelay_Valve,
#     OperatingMode := AutomaticMode
# );
# DO_ControlCompressorSuctionProcessVSG_01 := MBS_VSG_SuctionProcess.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_VSG_AS_SuctionProcess
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_VSG_AS_SuctionProcess
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CompressorControl;
# END_IF
#
# // METHOD Start of MBS_VSG_AS_SuctionProcess
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CompressorControl := MethodCall;
# Destination := DestinationPoint;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_VSG_AS_HorizontalMoveEncoder VSG_AS_HorizontalMoveEncoder ST // POU VSG_AS_HorizontalMoveEncoder body
# HRL_RGB_HorizontalMoveWithEncoder(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02_EncoderStart01 := EncoderStartPosition01,
#     DI03_EncoderTarget01 := EncoderTargetPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderTarget02 := EncoderTargetPosition02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingHorizontalVSG_01 := HRL_RGB_HorizontalMoveWithEncoder.DigitalOutputControl_01;
#
# // METHOD Abort of VSG_AS_HorizontalMoveEncoder
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of VSG_AS_HorizontalMoveEncoder
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of VSG_AS_HorizontalMoveEncoder
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := MovementDirection;
# EncoderTargetPosition01 := EncoderPositionHorizontal_01;
# EncoderTargetPosition02 := EncoderPositionHorizontal_02;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_VSG_AS_RotationMoveEncoder VSG_AS_RotationMoveEncoder ST // POU VSG_AS_RotationMoveEncoder body
# HRL_RGB_VerticalMoveWithEncoder(
#     MethodCall := MethodCall_RotationMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionRotation,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02_EncoderStart01 := EncoderStartPosition01,
#     DI03_EncoderTarget01 := EncoderTargetPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderTarget02 := EncoderTargetPosition02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingRotationVSG_01 := HRL_RGB_VerticalMoveWithEncoder.DigitalOutputControl_01;
#
# // METHOD Abort of VSG_AS_RotationMoveEncoder
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of VSG_AS_RotationMoveEncoder
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_RotationMove;
# END_IF
#
# // METHOD Start of VSG_AS_RotationMoveEncoder
# callCounterStart := callCounterStart + 1;
#
# MethodCall_RotationMove := MethodCall;
# Directionrotation := MovementDirection;
# EncoderTargetPosition01 := EncoderPositionRotation_01;
# EncoderTargetPosition02 := EncoderPositionRotation_02;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_VSG_AS_VerticalMoveEncoder VSG_AS_VerticalMoveEncoder ST // POU VSG_AS_VerticalMoveEncoder body
# HRL_RGB_VerticalMoveWithEncoder(
#     MethodCall := MethodCall_VerticalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionVertical,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor01,
#     DI02_EncoderStart01 := EncoderStartPosition01,
#     DI03_EncoderTarget01 := EncoderTargetPosition01,
#     DI04_EncoderStart02 := EncoderStartPosition02,
#     DI05_EncoderTarget02 := EncoderTargetPosition02,
#     TouchSensorRelief := TSR,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := TOF_Time_TSR,
#     OperatingMode := AutomaticMode
# );
# DO_MovingVerticalVSG_01 := HRL_RGB_VerticalMoveWithEncoder.DigitalOutputControl_01;
#
# // METHOD Abort of VSG_AS_VerticalMoveEncoder
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of VSG_AS_VerticalMoveEncoder
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_VerticalMove;
# END_IF
#
# // METHOD Start of VSG_AS_VerticalMoveEncoder
# callCounterStart := callCounterStart + 1;
#
# MethodCall_VerticalMove := MethodCall;
# DirectionVertical := MovementDirection;
# EncoderTargetPosition01 := EncoderPositionVertical_01;
# EncoderTargetPosition02 := EncoderPositionVertical_02;
# TSR := TouchSensorRelief;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_SST_PD_AS_HorizontalMove SST_PD_AS_HorizontalMove ST // POU SST_PD_AS_HorizontalMove body
# MBS_VSG_HorizontalMove(
#     MethodCall := MethodCall_CompressorControl,
#     EmergencyStopSignal := ESS,
#     Destination := DestinationHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := LightSensor_01,
#     DI02 := LightSensor_02,
#     DI03_EncoderStart01 := ,
#     DI04_EncoderStart02 := ,
#     DI05_EncoderStart03 := ,
#     DI06_EncoderStart04 := ,
#     DI07_EncoderStart05 := ,
#     DI08_EncoderStart06 := ,
#     DI09_EncoderTarget01 := ,
#     DI10_EncoderTarget02 := ,
#     DI11_EncoderTarget03 := ,
#     DI12_EncoderTarget04 := ,
#     DI13_EncoderTarget05 := ,
#     DI14_EncoderTarget06 := ,
#     PowerOFF_SelfSet := ,
#     TON_Time_PowerOFFSelfSet := ,
#     TON_Time_Compressor := PowerOnDelay_Compressor,
#     TON_Time_Valve := PowerOnDelay_Valve,
#     OperatingMode := AutomaticMode
# );
# DO_ControlCompressorPD_01 := MBS_VSG_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of SST_PD_AS_HorizontalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of SST_PD_AS_HorizontalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_CompressorControl;
# END_IF
#
# // METHOD Start of SST_PD_AS_HorizontalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_CompressorControl := MethodCall;
# DestinationHorizontal := DestinationPoint;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_SST_CB_AS_HorizontalMove SST_CB_AS_HorizontalMove ST // POU SST_CB_AS_HorizontalMove body
# SST_CB_HorizontalMove(
#     MethodCall := MethodCall_HorizontalMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionHorizontal,
#     InitStateDrive_Input := ,
#     DI01 := LightSensor_01,
#     DI02 := LightSensor_02,
#     TouchSensorRelief := ,
#     TOF_Time_MotorControl := TOF_Time_Motoransteuerung,
#     TOF_Time_TouchSensorRelief := ,
#     OperatingMode := AutomaticMode
# );
# DO_MovingConveyorBelt := SST_CB_HorizontalMove.DigitalOutputControl_01;
#
# // METHOD Abort of SST_CB_AS_HorizontalMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of SST_CB_AS_HorizontalMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_HorizontalMove;
# END_IF
#
# // METHOD Start of SST_CB_AS_HorizontalMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_HorizontalMove := MethodCall;
# DirectionHorizontal := DirectionPoint;
#
# jobRunning := TRUE;
# Start := 0;
# http://www.semanticweb.org/AgentProgramParams/FBType_MBS_DmPD_AS_RotationMove MBS_DmPD_AS_RotationMove ST // POU MBS_DmPD_AS_RotationMove body
# MBS_DmPD_RotationMove(
#     MethodCall := MethodCall_RotationMove,
#     EmergencyStopSignal := ESS,
#     Direction := DirectionRotation,
#     InitStateDrive_Input := ,
#     DI01 := TouchSensor_01,
#     DI02 := TouchSensor_02,
#     TouchSensorRelief := ,
#     TOF_Time_MotorControl := ,
#     TOF_Time_TouchSensorRelief := ,
#     OperatingMode := AutomaticMode
# );
# DO_MovingRotationPmPD_01 := MBS_DmPD_RotationMove.DigitalOutputControl_01;
#
# // METHOD Abort of MBS_DmPD_AS_RotationMove
# callCounterAbort := callCounterAbort + 1;
#
# // METHOD CheckState of MBS_DmPD_AS_RotationMove
# callCounterCheckState := callCounterCheckState + 1;
# IF NOT jobFinished THEN
# 	bBusy := TRUE;
# 	CheckState := 0;
# ELSE
# 	bBusy := FALSE;
# 	CheckState := 0;
# 	jobFinished := FALSE;
# 	State := ResetMethodCall;
# 	MethodCall := MethodCall_RotationMove;
# END_IF
#
# // METHOD Start of MBS_DmPD_AS_RotationMove
# callCounterStart := callCounterStart + 1;
#
# MethodCall_RotationMove := MethodCall;
# DirectionRotation := DirectionPoint;
#
# jobRunning := TRUE;
# Start := 0;
# POUs: 22
# ['FB_MyOpcUaMethod', 'JobMethode_Schablone', 'MBS_CB_AS_HorizontalMove', 'MBS_DmPD_AS_HorizontalMove', 'MBS_MR01_AS_HardeningProcess']

# %%
from groq import Groq
import json
import time

api_key_path = r"C:\Users\Alexander Verkhov\Desktop\APIKey_Groq.txt"
with open(api_key_path, "r", encoding="utf-8") as f:
    groq_api_key = f.read().strip()

client = Groq(api_key=groq_api_key)

CSS_DEFINITION = """
CSS-Modell (kurz):
- Capability: implementierungsunabhängige Beschreibung einer Funktion (was soll möglich sein).
- Skill: implementierte Funktion, die eine Capability konkret ausführt (wie wird es ausgeführt).
- Service: angebotene Schnittstelle, über die ein Skill genutzt wird (z.B. API, OPC UA, PLC-Job-Interface).
Bewerte anhand des Codes, ob dieser POU einen ausführbaren Skill (Job) darstellt.
"""

# %%
SKILL_SCHEMA = {
  "name": "css_skill_classifier",
  "schema": {
    "type": "object",
    "additionalProperties": False,
    "properties": {
      "is_skill": {"type": "boolean"},
      "capability_name": {"type": "string"},
      "skill_name": {"type": "string"},
      "service_interface": {"type": "string"},
      "reason_short": {"type": "string"},
      "evidence": {
        "type": "array",
        "items": {"type": "string"},
        "minItems": 1,
        "maxItems": 6
      },
      "inputs_guess": {"type": "array", "items": {"type": "string"}},
      "outputs_guess": {"type": "array", "items": {"type": "string"}}
    },
    "required": ["is_skill", "capability_name", "skill_name", "service_interface", "reason_short", "evidence", "inputs_guess", "outputs_guess"]
  }
}

# %%
import json

EXPECTED_KEYS = [
    "is_skill",
    "capability_name_realworld",
    "skill_name",
    "service_interface",
    "real_world_effect_guess",
    "actuators_guess",
    "sensors_guess",
    "reason_short",
    "evidence",
    "inputs_guess",
    "outputs_guess",
]

def classify_pou_as_css_skill(pou_row: dict, model: str = "llama-3.1-8b-instant"):
    code = pou_row["code"] or ""

    prompt = f"""
{CSS_DEFINITION}

Gib ausschließlich EIN JSON-Objekt zurück (kein Markdown, kein Text außenrum).
Das JSON MUSS genau diese Keys enthalten:
{EXPECTED_KEYS}

Regeln:
- capability_name_realworld: 3 bis 8 Wörter, deutsch, beschreibt die physische Wirkung (z.B. "Vertikalachse encodergeführt bewegen").
  NICHT erlaubt: "abstrakt", "n/a", "unknown", "Skill", "Capability".
- real_world_effect_guess: 1 Satz, konkret: was wird bewegt/geschaltet/gemessen? Nutze nur Hinweise aus dem Code.
- actuators_guess: Liste von Aktor-Signalen/Outputs aus dem Code (z.B. DO_...).
- sensors_guess: Liste von Sensor/Encoder/DI Signalen aus dem Code (z.B. TouchSensor..., Encoder...).
- evidence: 2 bis 6 kurze Code-Zeilen wörtlich, die deine Aussage stützen.

POU-Name: {pou_row["name"]}
Sprache: {pou_row["lang"]}

Code:
{code}
""".strip()

    resp = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "Return valid JSON only."},
            {"role": "user", "content": prompt},
        ],
        temperature=0.0,
        max_completion_tokens=600,
        response_format={"type": "json_object"},  # <-- wichtig
    )

    data = json.loads(resp.choices[0].message.content)

    # Minimal-Validation (damit du merkst, wenn das Modell "ausbricht")
    missing = [k for k in EXPECTED_KEYS if k not in data]
    if missing:
        raise ValueError(f"Missing keys in JSON: {missing}")

    return data

# %%
results = []
for i, r in enumerate(rows, start=1):
    try:
        out = classify_pou_as_css_skill(r)
        out["_pou_iri"] = r["pou_iri"]
        out["_pou_lang"] = r["lang"]
        results.append(out)
        print(f"[{i}/{len(rows)}] {r['name']} -> is_skill={out['is_skill']}")
        time.sleep(0.2)  # optional: etwas drosseln
    except Exception as e:
        print(f"[{i}/{len(rows)}] ERROR bei {r['name']}: {e}")

with open("css_skill_results.json", "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)

print("Fertig. Ergebnisse:", len(results))
# Out:
# [1/22] FB_MyOpcUaMethod -> is_skill=True
# [2/22] JobMethode_Schablone -> is_skill=True
# [3/22] MBS_CB_AS_HorizontalMove -> is_skill=True
# [4/22] MBS_DmPD_AS_HorizontalMove -> is_skill=True
# [5/22] MBS_MR01_AS_HardeningProcess -> is_skill=True
# [6/22] MBS_MR02_AS_CuttingProcess -> is_skill=True
# [7/22] MBS_VSG_AS_VerticalMove -> is_skill=True
# [8/22] SST_CS_AS_ColorDetection -> is_skill=True
# [9/22] VSG_AS_CompressorControl -> is_skill=True
# [10/22] HRL_CB_AS_HorizontalMoveSensors -> is_skill=True
# [11/22] HRL_RGB_AS_HorizontalMoveEncoders -> is_skill=True
# [12/22] HRL_RGB_AS_HorizontalMoveSensors -> is_skill=True
# [13/22] HRL_RGB_AS_VerticalMoveEncoders -> is_skill=True
# [14/22] MBS_MR01_AS_HorizontalMoveSensors -> is_skill=True
# [15/22] MBS_VSG_AS_HorizontalMove -> is_skill=True
# [16/22] MBS_VSG_AS_SuctionProcess -> is_skill=True
# [17/22] VSG_AS_HorizontalMoveEncoder -> is_skill=True
# [18/22] VSG_AS_RotationMoveEncoder -> is_skill=True
# [19/22] VSG_AS_VerticalMoveEncoder -> is_skill=True
# [20/22] SST_PD_AS_HorizontalMove -> is_skill=True
# [21/22] SST_CB_AS_HorizontalMove -> is_skill=True
# [22/22] MBS_DmPD_AS_RotationMove -> is_skill=True
# Fertig. Ergebnisse: 22
