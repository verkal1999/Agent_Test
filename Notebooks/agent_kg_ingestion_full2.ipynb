# %% [markdown]
# # Wissensgraph-Ingestion für das Beckhoff-HRL-Projekt
#
# Dieses Notebook liest die vorhandenen JSON-Dateien aus dem Beckhoff-Projekt (insbesondere
# `program_io_with_mapping.json` und `io_mappings.json`) und befüllt die Ontologie `ParamDiag_Agent.ttl`
# mit Instanzen und Beziehungen. Es werden dabei Programme, Variablen, Unterprogramme,
# Mappings zwischen Variablen sowie Hardware-Adressen berücksichtigt.
#
# ## benötigte Dateien
#
# - **ParamDiag_Agent.ttl**: Basisontologie mit Klassen und Properties.
# - **program_io_with_mapping.json**: enthält pro POU/Programm alle deklarierten
#   Eingänge/Ausgänge sowie die Aufrufe (Subcalls) anderer Programme mit Zuordnung der
#   formalen Parameter zu den tatsächlichen Variablen.
# - **io_mappings.json**: enthält für jede PLC-Variable die Zuordnung zu einer physischen
#   I/O-Adresse und das zugehörige Roh-XML aus dem Mapping.
#
# Das Notebook erzeugt eine neue Turtle-Datei `ParamDiag_Agent_filled.ttl` mit den
# angereicherten Triple.

# %%
from rdflib import Graph, Namespace, RDF, URIRef, Literal
from pathlib import Path
import json

twincat_folder = Path(r"C:\Users\Alexander Verkhov\OneDrive\Dokumente\MPA\TestProjektTwinCATEvents")
slnfile_str = r"C:\Users\Alexander Verkhov\OneDrive\Dokumente\MPA\TestProjektTwinCATEvents\TestProjektTwinCATEvents.sln"
kg_cleaned_path = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test_cleaned.ttl"
kg_to_fill_path = r"D:\MA_Python_Agent\MSRGuard_Anpassung\KGs\Test_filled.ttl"
objects_path = Path(slnfile_str.replace('.sln', '_objects.json'))
prog_io_mappings_path = twincat_folder / "program_io_with_mapping.json"
io_map_path = twincat_folder / "io_mappings.json"

# Namespaces definieren
AG = Namespace('http://www.semanticweb.org/AgentProgramParams/')
DP = Namespace('http://www.semanticweb.org/AgentProgramParams/dp_')
OP = Namespace('http://www.semanticweb.org/AgentProgramParams/op_')

# Hilfsfunktion zur Generierung von URIs aus Namen

def make_uri(name: str) -> URIRef:
    """
    Baut eine IRI auf Basis eines Namens.
    Konvention:
      - '^'  -> '_'
      - '.'  -> '__dot__'
      - ' '  -> '_'
    """
    safe = (
        name
        .replace('^', '__dach__')
        .replace('.', '__dot__')
        .replace(' ', '__leerz__')
    )
    return URIRef(AG + safe)

# Bestehenden Graph laden
kg = Graph()
with open(kg_cleaned_path, "r", encoding="utf-8") as fkg:
    kg.parse(file=fkg, format="turtle")

# Dictionaries für später

# Programme: Name -> URIRef
prog_uris: dict[str, URIRef] = {}

# Programm-lokale Variablen:
# Schlüssel = (Programmname, Variablenname)
var_uris: dict[tuple[str, str], URIRef] = {}

channel_uris = {}

# Hardware-Variablen (GVL / IO etc.): plc_var-String -> URIRef
hw_var_uris: dict[str, URIRef] = {}
pending_ext_hw_links: list[tuple[URIRef, str]] = []

def get_program_uri(prog_name: str) -> URIRef:
    """
    Liefert den URI eines Programms und legt ihn an, falls er noch nicht existiert.
    """
    uri = prog_uris.get(prog_name)
    if uri is None:
        uri = make_uri(f"Program_{prog_name}")
        kg.add((uri, RDF.type, AG.class_Program))
        prog_uris[prog_name] = uri
    return uri


def get_local_var_uri(prog_name: str, var_name: str) -> URIRef:
    """
    Erzeugt eine eindeutig je Programm getrennte Variablenressource.
    Gleiche Namen in unterschiedlichen Programmen -> unterschiedliche URIs.
    """
    key = (prog_name, var_name)
    uri = var_uris.get(key)
    if uri is None:
        raw_id = f"Var_{prog_name}_{var_name}"
        uri = make_uri(raw_id)
        kg.add((uri, RDF.type, AG.class_Variable))
        var_uris[key] = uri
    return uri

# %%
# GVL-Index aus Objects-JSON bauen:
# Kurzname (z. B. "Err_detected") -> Menge vollqualifizierter GVL-Variablen (z. B. {"GVL_Diagnose.Err_detected"})
with open(objects_path,
          "r", encoding="utf-8") as f:
    objects_data = json.load(f)

gvl_short_to_full: dict[str, set[str]] = {}

for obj in objects_data:
    if obj.get("kind") == "GVL":
        gvl_name = obj.get("name")  # z. B. "GVL_Diagnose" oder einfach "GVL"
        for glob in obj.get("globals", []):
            short = glob.get("name")
            if not short:
                continue

            # Vollqualifizierter Name der globalen Variable
            if gvl_name == "GVL":
                full = f"GVL.{short}"
            else:
                full = f"{gvl_name}.{short}"

            gvl_short_to_full.setdefault(short, set()).add(full)

# %%
# GVL-Index aus Objects-JSON bauen:
# Kurzname (z. B. "Err_detected") -> Menge vollqualifizierter GVL-Variablen (z. B. {"GVL_Diagnose.Err_detected"})
with open(objects_path,
          "r", encoding="utf-8") as f:
    objects_data = json.load(f)

gvl_short_to_full: dict[str, set[str]] = {}
gvl_full_to_type: dict[str, str] = {}   # <--- NEU

for obj in objects_data:
    if obj.get("kind") == "GVL":
        gvl_name = obj.get("name")  # z. B. "GVL" oder "OPCUA"
        for glob in obj.get("globals", []):
            short = glob.get("name")
            if not short:
                continue

            # Vollqualifizierter Name z. B. "GVL.Start" oder "OPCUA.bool1"
            if gvl_name == "GVL":
                full = f"GVL.{short}"
            else:
                full = f"{gvl_name}.{short}"

            gvl_short_to_full.setdefault(short, set()).add(full)

            vtype = glob.get("type")          # z. B. BOOL, INT, STRING, ...
            if vtype:
                gvl_full_to_type[full] = vtype   # <--- NEU

# Programme und Variablen aus der JSON einlesen (neues Schema)
with open(prog_io_mappings_path,
          "r", encoding="utf-8") as f:
    prog_data = json.load(f)

for entry in prog_data:
    prog_name = entry.get("Programm_Name")  # neuer Schlüsselname
    if not prog_name:
        continue

    # Programmknoten anlegen (jetzt über Helper)
    prog_uri = get_program_uri(prog_name)

    # Hilfsfunktion: wähle internen oder externen Namen (zur Benennung der Var_... Knoten)
    def pick_var(item: dict) -> str | None:
        ext = item.get("external")
        return ext.split('.')[-1] if ext else item.get('internal')

    # Hilfsfunktion: aus einem externen Variablennamen den passenden URI bestimmen.
    # Dabei werden:
    #  - vollqualifizierte GVL-Namen (z. B. "GVL_SST.SST_LS_Eingang") direkt auf GVL-Variablen gemappt
    #  - Kurz-Namen (z. B. "Err_detected") über den GVL-Index auf z. B. "GVL_Diagnose.Err_detected" gemappt
    #  - sonstige Namen als lokale Variablen in Programmen interpretiert
    def get_ext_var_uri(external: str | None, caller_prog: str):
        if not external:
            return None

        # Fall 1: externer Name hat keinen Punkt -> könnte GVL-Global oder lokale Var sein
        if '.' not in external:
            # zuerst prüfen, ob der Kurzname einer GVL-Variablen entspricht
            if external in gvl_short_to_full:
                full_names = sorted(gvl_short_to_full[external])
                full = full_names[0]  # falls mehrere, deterministisch das erste nehmen

                uri = hw_var_uris.get(full)
                if uri is None:
                    uri = make_uri(full)
                    kg.add((uri, RDF.type, AG.class_Variable))
                    hw_var_uris[full] = uri
                return uri

            # sonst: lokale Variable des aufrufenden Programms
            return get_local_var_uri(caller_prog, external)

        # Fall 2: externer Name ist bereits qualifiziert "Prefix.Suffix"
        prefix, suffix = external.split('.', 1)

        # 2a) GVL oder GV Variablen: globale Variable mit vollem Namen
        if prefix.startswith('GVL') or prefix.startswith('GV'):
            uri = hw_var_uris.get(external)
            if uri is None:
                uri = make_uri(external)
                kg.add((uri, RDF.type, AG.class_Variable))
                hw_var_uris[external] = uri
            return uri

        # 2b) Präfix ist ein Programmname: lokale Variable in diesem Programm
        return get_local_var_uri(prefix, suffix)

    # -----------------------------
    # 2.1 Inputs / Outputs / InOuts
    # -----------------------------
    for sec in ("inputs", "outputs", "inouts"):
        for var in entry.get(sec, []):
            vname = pick_var(var)
            if not vname:
                continue

            # lokale Variable dieses Programms
            v_uri = get_local_var_uri(prog_name, vname)

            # Input/Output-Beziehung zum Programm
            if sec == "inputs":
                kg.add((prog_uri, AG.op_hasInputVariable, v_uri))
            elif sec == "outputs":
                kg.add((prog_uri, AG.op_hasOutputVariable, v_uri))
            else:  # inouts
                kg.add((prog_uri, AG.op_hasInputVariable, v_uri))
                kg.add((prog_uri, AG.op_hasOutputVariable, v_uri))

            # Programm nutzt Variable
            kg.add((prog_uri, AG.op_usesVariable, v_uri))

            # Mapping interne → externe Variable dieses Programms
            internal = var.get("internal")
            external = var.get("external")
            if internal and external:
                # interne Schnittstellenvariable dieses Programms
                int_uri = get_local_var_uri(prog_name, internal)

                # externe Variable im FBD (kann z. B. GVL, OPCUA, HRL_... sein)
                ext_uri = get_ext_var_uri(external, prog_name)

                if ext_uri is not None and int_uri != ext_uri:
                    kg.add((int_uri, AG.op_isMappedToVariable, ext_uri))

                # exakte Hardware/Globale-Referenz merken (z. B. GVL_Diagnose.Err_detected)
                if ext_uri is not None:
                    pending_ext_hw_links.append((ext_uri, external))

    # -----------------------------
    # 2.2 Temporäre Variablen (temps)
    # -----------------------------
    for temp in entry.get("temps", []):
        vname = temp.get("name")
        if vname:
            v_uri = get_local_var_uri(prog_name, vname)
            kg.add((prog_uri, AG.op_hasInternVariable, v_uri))
            kg.add((prog_uri, AG.op_usesVariable, v_uri))

    # -----------------------------
    # 2.3 Subcalls und Parameter-Mappings
    # -----------------------------
    for sc in entry.get("subcalls", []):
        sub_prog = sc.get("SubNetwork_Name")   # Name des aufgerufenen Bausteins
        instance = sc.get("instanceName")      # Instanzname im aufrufenden Programm

        if sub_prog:
            sub_uri = get_program_uri(sub_prog)
            # Subprogramm-Beziehung: Subprogramm gehört zu aufrufendem Programm
            kg.add((sub_uri, AG.op_isSubProgramOf, prog_uri))

        if instance and sub_prog:
            # Instanzvariable liegt im aufrufenden Programm
            inst_uri = get_local_var_uri(prog_name, instance)
            kg.add((inst_uri, AG.op_isMappedToProgram, sub_uri))

        # Parameter-Mappings: interne (im Subprogramm) -> externe (im aufrufenden Programm)
        for param in sc.get("inputs", []):
            internal = param.get("internal")
            external = param.get("external")
            if internal and external and sub_prog:
                # interne Variable gehört zum Subprogramm
                int_uri = get_local_var_uri(sub_prog, internal)

                # externe Variable gehört zum aufrufenden Programm (ggf. GVL via Kurzname)
                ext_uri = get_ext_var_uri(external, prog_name)

                if ext_uri is not None and int_uri != ext_uri:
                    kg.add((int_uri, AG.op_isMappedToVariable, ext_uri))
                if ext_uri is not None:
                    pending_ext_hw_links.append((ext_uri, external))

        for param in sc.get("outputs", []):
            internal = param.get("internal")
            external = param.get("external")
            if internal and external and sub_prog:
                int_uri = get_local_var_uri(sub_prog, internal)
                ext_uri = get_ext_var_uri(external, prog_name)

                if ext_uri is not None and int_uri != ext_uri:
                    kg.add((int_uri, AG.op_isMappedToVariable, ext_uri))
                if ext_uri is not None:
                    pending_ext_hw_links.append((ext_uri, external))

    # -----------------------------
    # 2.4 Programmkode als Daten-Property speichern (falls vorhanden)
    # -----------------------------
    code = entry.get("program_code")
    if code:
        kg.add((prog_uri, DP.hasProgramCode, Literal(code)))

# %%
# Hardware und IO Channel Informationen einlesen und in den KG schreiben
from rdflib.namespace import XSD, RDF
import json

# Pfad anpassen, falls nötig
#io_mappings_path = r"C:\Users\Alexander Verkhov\OneDrive\Dokumente\MPA\twincat2\TwinCAT\io_mappings.json"
# Alternativ relativ:
# io_mappings_path = "io_mappings.json"

with open(io_map_path, "r", encoding="utf-8") as f:
    io_data = json.load(f)

for entry in io_data:
    plc_var = entry.get("plc_var")
    if not plc_var:
        continue

    # Voll qualifizierte PLC Variable wie "GVL.diNotAus_Kanal_A"
    # Echte Hardware und GVL Variablen landen in hw_var_uris
    var_uri = hw_var_uris.get(plc_var)
    if var_uri is None:
        # Hier KEIN Kürzen auf Suffix, immer den voll qualifizierten Namen nehmen
        var_uri = make_uri(plc_var)
        kg.add((var_uri, RDF.type, AG.class_Variable))
        hw_var_uris[plc_var] = var_uri

    # 1) Hardware Adresse aus io_mappings.json
    hw_addr = entry.get("ea_address")
    if hw_addr:
        # dp_hasHardwareAddress(VarX, xsd:string)
        kg.add((var_uri, DP.hasHardwareAddress, Literal(hw_addr)))

    # 2) IO Channel Instanz für class_IOChannel anlegen
    io_path = entry.get("io_path")
    channel_label = entry.get("channel_label")
    io_uri = None

    if io_path:
        # IO Channel Ressource
        io_uri = make_uri(f"IOChannel_{io_path}")
        kg.add((io_uri, RDF.type, AG.class_IOChannel))



        # Variable mit IO Channel verknüpfen
        kg.add((var_uri, OP.isBoundToChannel, io_uri))

    # 3) Rohes XML als XMLLiteral im KG ablegen
    raw_xml = entry.get("io_raw_xml")
    if raw_xml:
        # Roh-XML als normaler String speichern, NICHT als XMLLiteral
        kg.add((var_uri, DP.ioRawXml, Literal(raw_xml, datatype=XSD.string)))

# 4) Externe Variablen aus den Programmen mit ihren Hardware GVL Variablen verknüpfen
#    pending_ext_hw_links wurde in der Programm Schleife gefüllt
for ext_uri, external_full in pending_ext_hw_links:
    # external_full ist z.B. "GVL_SST.SST_LS_Eingang"
    hw_uri = hw_var_uris.get(external_full)
    if hw_uri is not None and ext_uri != hw_uri:
        # z.B. Var_SST_LS_Eingang → GVL_SST.SST_LS_Eingang
        kg.add((ext_uri, AG.op_isMappedToVariable, hw_uri))

# %%
import json
from pathlib import Path
from rdflib import RDF, Literal, Graph

# Vorausgesetzt: g, AG, DP sind bereits definiert, z. B.
# from rdflib import Graph, Namespace
# g = Graph()
# AG = Namespace("http://www.semanticweb.org/AgentProgramParams/")
# DP = Namespace("http://www.semanticweb.org/AgentProgramParams/dp_")

# Pfad zu deiner GVL-JSON
gvl_path = Path(r"C:\Users\Alexander Verkhov\OneDrive\Dokumente\MPA\TestProjektTwinCATEvents\gvl_globals.json")

# JSON laden (Liste von GVL-Objekten, siehe gvl_globals.json)
gvl_data = json.loads(gvl_path.read_text(encoding="utf-8"))

def make_var_name(gvl_name: str, var_name: str) -> str:
    """
    Erzeugt den Namen für die class_Variable:
    z. B. GVL + '__dot__' + Start -> 'GVL__dot__Start'
    """
    return f"{gvl_name}__dot__{var_name}"

# Alle GVL-Variablen als class_Variable in den Graphen schreiben
for gvl in gvl_data:
    gvl_name = gvl["name"]       # z. B. "GVL" oder "OPCUA"
    for gv in gvl.get("globals", []):
        base_name = gv["name"]   # z. B. "Start", "Z1", "TriggerD2", ...

        var_local = make_var_name(gvl_name, base_name)
        var_uri   = AG[var_local]

        # Typ: class_Variable
        kg.add((var_uri, RDF.type, AG.class_Variable))

        # Name der Variable (mit Präfix)
        kg.add((var_uri, DP.dp_hasVariableName, Literal(var_local)))

        # Typ / Datentyp der Variable, falls du es in der Ontologie abbildest
        if gv.get("type"):
            # ggf. Predicate an deine Ontologie anpassen (z. B. dp_hasVariableType)
            kg.add((var_uri, DP.dp_hasVariableType, Literal(gv["type"])))

        # Initialwert
        if gv.get("init") is not None:
            # ggf. Predicate anpassen (z. B. dp_hasInitialValue)
            kg.add((var_uri, DP.dp_hasInitialValue, Literal(gv["init"])))

        # Adresse / Hardware-Mapping (falls genutzt)
        if gv.get("address"):
            # ggf. Predicate anpassen (z. B. dp_hasAddress / dp_hasHardwareAddress)
            kg.add((var_uri, DP.dp_hasHardwareAddress, Literal(gv["address"])))

print(f"{sum(len(g['globals']) for g in gvl_data)} GVL-Variablen als class_Variable in den KG geschrieben.")
# Out:
# 23 GVL-Variablen als class_Variable in den KG geschrieben.

# %%
# Graph speichern
kg.serialize(kg_to_fill_path, format='turtle')
print('Ingestion abgeschlossen: Testfilled.ttl wurde erstellt.')
# Out:
# Ingestion abgeschlossen: Testfilled.ttl wurde erstellt.

# %% [markdown]
# from rdflib import Graph, URIRef, BNode
#
# def makePropertyreflexive(g: Graph, propertyURI: str) -> int:
#     """
#     Sucht alle Tripel (?s propertyURI ?o) und fügt zu jedem
#     ein 'Rückwärts-Tripel' (?o propertyURI ?s) hinzu,
#     falls es noch nicht existiert.
#
#     Rückgabe: Anzahl neu hinzugefügter Tripel.
#     """
#     prop = URIRef(propertyURI)
#     to_add = []
#
#     for s, p, o in g.triples((None, prop, None)):
#         # Nur URIs / Blank Nodes als Objekt spiegeln, Literale machen hier keinen Sinn
#         if isinstance(o, (URIRef, BNode)) and (o, prop, s) not in g:
#             to_add.append((o, prop, s))
#
#     for triple in to_add:
#         g.add(triple)
#         print(str(triple) + " hinzugefügt.")
#
#     return len(to_add)
#
# added = makePropertyreflexive(kg, "http://www.semanticweb.org/AgentProgramParams/op_isMappedToVariable")
# print(f"{added} Rückwärts-Tripel hinzugefügt.")
#
# # Graph speichern
# kg.serialize(r"D:\MA_Python_Agent\MSRGuard\KGs\ParamDiag_Agent_filled2.ttl", format='turtle')
# print('Ingestion abgeschlossen: ParamDiag_Agent_filled.ttl wurde erstellt.')

# %%
results=kg.query("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX ag:<http://www.semanticweb.org/AgentProgramParams/>
SELECT * WHERE { 

# ?v a ag:class_Variable.
ag:Program_HRL_SkillSet ag:op_usesVariable ?v.
# ?v ag:op_isMappedToProgram ?prog.
# ?prog ag:dp_hasProgramCode ?code.
}
""")


# Ergebnisse ausgeben (printen)
print("### SPARQL-Abfrage-Ergebnisse ###")
print(f"Gefundene Ergebnisse: {len(results)}")
print("-" * 30)

# Ausgabe der Ergebnisse in einer lesbaren Form
for row in results:
    # Die Ergebnisse sind Tupel, die den Variablen in der SELECT-Klausel entsprechen
    # In diesem Fall: ?v, ?prog, ?code
    print(f"Variable (?v):   {row.v}")
    print(f"Programm (?prog): {row.prog}")
    print(f"Code (?code):    {row.code}")
    print("-" * 30)

# Zusätzliche Ausgabe als DataFrame (falls Sie pandas nutzen)
try:
    import pandas as pd
    # Konvertiert die rdflib-Ergebnisse in einen Pandas DataFrame
    df = pd.DataFrame(results, columns=list(results.vars))
    print("\n### Ergebnisse als Pandas DataFrame ###")
    print(df)
except ImportError:
    print("Installieren Sie 'pandas', um die Ergebnisse als DataFrame anzuzeigen: !pip install pandas")
# Out:
# ### SPARQL-Abfrage-Ergebnisse ###
# Gefundene Ergebnisse: 11
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_CB_MoveForwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_CB_AS_HorizontalMoveSensors
# Code (?code):    import time
#
# def HRL_CB_AS_HorizontalMoveSensors(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: bool, DirectionHorizontal: bool, V_20000000003, LightBarrierSensor_01: UDint, LightBarrierSensor_02: bool, V_20000000006, V_20000000007, V_20000000008, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_MultipleInputSensors(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009):
#         result = AutomaticMode
#         return result
#     V_20000000010 = AxisControl_MultipleInputSensors(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, LightBarrierSensor_01, LightBarrierSensor_02, V_20000000006, V_20000000007, V_20000000008, AutomaticMode)
#     DO_MovingConveyorBelt = V_20000000010
#     print('Value of DO_MovingConveyorBelt:', DO_MovingConveyorBelt)
#     return {'DO_MovingConveyorBelt': DO_MovingConveyorBelt}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_CB_MoveBackwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_CB_AS_HorizontalMoveSensors
# Code (?code):    import time
#
# def HRL_CB_AS_HorizontalMoveSensors(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: bool, DirectionHorizontal: bool, V_20000000003, LightBarrierSensor_01: UDint, LightBarrierSensor_02: bool, V_20000000006, V_20000000007, V_20000000008, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_MultipleInputSensors(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009):
#         result = AutomaticMode
#         return result
#     V_20000000010 = AxisControl_MultipleInputSensors(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, LightBarrierSensor_01, LightBarrierSensor_02, V_20000000006, V_20000000007, V_20000000008, AutomaticMode)
#     DO_MovingConveyorBelt = V_20000000010
#     print('Value of DO_MovingConveyorBelt:', DO_MovingConveyorBelt)
#     return {'DO_MovingConveyorBelt': DO_MovingConveyorBelt}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveBackwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_HorizontalMoveSensors
# Code (?code):    import time
#
# def HRL_RGB_AS_HorizontalMoveSensors(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: bool, DirectionHorizontal: int, V_20000000003, TouchSensor01: UDint, TouchSensor02: UDint, TSR: bool, V_20000000007, TOF_Time_TSR: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_MultipleInputSensors(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009):
#         result = AutomaticMode
#         return result
#     V_20000000010 = AxisControl_MultipleInputSensors(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, TouchSensor01, TouchSensor02, TSR, V_20000000007, TOF_Time_TSR, AutomaticMode)
#     DO_MovingHorizontalRGB_01 = V_20000000010
#     print('Value of DO_MovingHorizontalRGB_01:', DO_MovingHorizontalRGB_01)
#     return {'DO_MovingHorizontalRGB_01': DO_MovingHorizontalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveForwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_HorizontalMoveSensors
# Code (?code):    import time
#
# def HRL_RGB_AS_HorizontalMoveSensors(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: bool, DirectionHorizontal: int, V_20000000003, TouchSensor01: UDint, TouchSensor02: UDint, TSR: bool, V_20000000007, TOF_Time_TSR: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_MultipleInputSensors(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009):
#         result = AutomaticMode
#         return result
#     V_20000000010 = AxisControl_MultipleInputSensors(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, TouchSensor01, TouchSensor02, TSR, V_20000000007, TOF_Time_TSR, AutomaticMode)
#     DO_MovingHorizontalRGB_01 = V_20000000010
#     print('Value of DO_MovingHorizontalRGB_01:', DO_MovingHorizontalRGB_01)
#     return {'DO_MovingHorizontalRGB_01': DO_MovingHorizontalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveVerticalForwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_VerticalMoveEncoders
# Code (?code):    import time
#
# def HRL_RGB_AS_VerticalMoveEncoders(AlwaysTrue: bool, MethodCall_VerticalMove: bool, ESS: UDint, DirectionVertical: UDint, V_20000000003, TouchSensor01: bool, EncoderStartPosition01: UDint, EncoderTargetPosition01: UDint, EncoderStartPosition02: bool, EncoderTargetPosition02: bool, TSR: UDint, V_20000000010, TOF_TSR_TIME: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_VerticalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_Encoder(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009, V_20000000010, V_20000000011, V_20000000012):
#         result = AutomaticMode
#         return result
#     V_20000000013 = AxisControl_Encoder(MethodCall_VerticalMove, ESS, DirectionVertical, V_20000000003, TouchSensor01, EncoderStartPosition01, EncoderTargetPosition01, EncoderStartPosition02, EncoderTargetPosition02, TSR, V_20000000010, TOF_TSR_TIME, AutomaticMode)
#     DO_MovingVerticalRGB_01 = V_20000000013
#     print('Value of DO_MovingVerticalRGB_01:', DO_MovingVerticalRGB_01)
#     return {'DO_MovingVerticalRGB_01': DO_MovingVerticalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveVerticalBackwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_VerticalMoveEncoders
# Code (?code):    import time
#
# def HRL_RGB_AS_VerticalMoveEncoders(AlwaysTrue: bool, MethodCall_VerticalMove: bool, ESS: UDint, DirectionVertical: UDint, V_20000000003, TouchSensor01: bool, EncoderStartPosition01: UDint, EncoderTargetPosition01: UDint, EncoderStartPosition02: bool, EncoderTargetPosition02: bool, TSR: UDint, V_20000000010, TOF_TSR_TIME: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_VerticalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_Encoder(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009, V_20000000010, V_20000000011, V_20000000012):
#         result = AutomaticMode
#         return result
#     V_20000000013 = AxisControl_Encoder(MethodCall_VerticalMove, ESS, DirectionVertical, V_20000000003, TouchSensor01, EncoderStartPosition01, EncoderTargetPosition01, EncoderStartPosition02, EncoderTargetPosition02, TSR, V_20000000010, TOF_TSR_TIME, AutomaticMode)
#     DO_MovingVerticalRGB_01 = V_20000000013
#     print('Value of DO_MovingVerticalRGB_01:', DO_MovingVerticalRGB_01)
#     return {'DO_MovingVerticalRGB_01': DO_MovingVerticalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveHorizontalForwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_HorizontalMoveEncoders
# Code (?code):    import time
#
# def HRL_RGB_AS_HorizontalMoveEncoders(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: UDint, DirectionHorizontal: UDint, V_20000000003, TouchSensor01: bool, EncoderStartPosition01: UDint, EncoderTargetPosition01: UDint, EncoderStartPosition02: bool, EncoderTargetPosition02: bool, TSR: UDint, V_20000000010, TOF_Time_TSR: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_Encoder(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009, V_20000000010, V_20000000011, V_20000000012):
#         result = AutomaticMode
#         return result
#     V_20000000013 = AxisControl_Encoder(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, TouchSensor01, EncoderStartPosition01, EncoderTargetPosition01, EncoderStartPosition02, EncoderTargetPosition02, TSR, V_20000000010, TOF_Time_TSR, AutomaticMode)
#     DO_MovingHorizontalRGB_01 = V_20000000013
#     print('Value of DO_MovingHorizontalRGB_01:', DO_MovingHorizontalRGB_01)
#     return {'DO_MovingHorizontalRGB_01': DO_MovingHorizontalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_Skill_RGB_MoveHorizontalBackwards
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_AS_HorizontalMoveEncoders
# Code (?code):    import time
#
# def HRL_RGB_AS_HorizontalMoveEncoders(AlwaysTrue: bool, MethodCall_HorizontalMove: bool, ESS: UDint, DirectionHorizontal: UDint, V_20000000003, TouchSensor01: bool, EncoderStartPosition01: UDint, EncoderTargetPosition01: UDint, EncoderStartPosition02: bool, EncoderTargetPosition02: bool, TSR: UDint, V_20000000010, TOF_Time_TSR: bool, AutomaticMode):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def EXECUTE(V_10000000001):
#         """EXECUTE block – original ST-Code:
# CASE state OF
# 	0:
# 		IF jobRunning THEN
# 			state := state + 1;
# 		END_IF
#
# 	1:
# 		IF ResetMethodCall THEN
# 			jobRunning := FALSE;
# 			jobFinished := TRUE;
# 			state := 0;
# 			MethodCall_HorizontalMove := FALSE;
# 		END_IF
#
# END_CASE"""
#         result = AlwaysTrue
#         return result
#
#     def AxisControl_Encoder(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009, V_20000000010, V_20000000011, V_20000000012):
#         result = AutomaticMode
#         return result
#     V_20000000013 = AxisControl_Encoder(MethodCall_HorizontalMove, ESS, DirectionHorizontal, V_20000000003, TouchSensor01, EncoderStartPosition01, EncoderTargetPosition01, EncoderStartPosition02, EncoderTargetPosition02, TSR, V_20000000010, TOF_Time_TSR, AutomaticMode)
#     DO_MovingHorizontalRGB_01 = V_20000000013
#     print('Value of DO_MovingHorizontalRGB_01:', DO_MovingHorizontalRGB_01)
#     return {'DO_MovingHorizontalRGB_01': DO_MovingHorizontalRGB_01}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_ControlOfOutputs
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_ControlOfOutputs
# Code (?code):    import time
#
# def HRL_ControlOfOutputs(F1: bool, A2: bool, CB_Forwards: bool, Start: bool, F4: bool, CB_Backwards: bool, RGB_Forwards01: bool, RGB_Forwards02: bool, A6: bool, Init_RGB_Forwards: bool, RGB_Backwards01: bool, RGB_Backwards02: bool, Init_RGB_Backwards: bool, RGB_VertikalDown01, RGB_VertikalDown02, Init_RGB_VertikalDown, RGB_VertikalUp01, RGB_VertikalUp02, Init_RGB_VertikalUp, RGB_HorizontalForwards01, Init_RGB_HorizontalForwads, RGB_HorizontalBackwards01, RGB_HorizontalBackwards02, Init_RGB_HorizontalBackwards, A1):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def OR_1(V_10000000001, V_10000000002):
#         result = F1 or A2
#         return result
#     V_10000000003 = OR_1(F1, A2)
#
#     def AND_1(V_10000000003, V_10000000004):
#         result = V_10000000003 and CB_Forwards
#         return result
#     V_10000000005 = AND_1(V_10000000003, CB_Forwards)
#
#     def AND_2(V_10000000006, V_10000000007):
#         result = Start and F4
#         return result
#     V_10000000008 = AND_2(Start, F4)
#
#     def OR_2(V_10000000005, V_10000000008):
#         result = V_10000000005 or V_10000000008
#         return result
#     V_10000000009 = OR_2(V_10000000005, V_10000000008)
#
#     def OR_3(V_20000000000, V_20000000001):
#         result = F1 or A2
#         return result
#     V_20000000002 = OR_3(F1, A2)
#
#     def AND_3(V_20000000002, V_20000000003):
#         result = V_20000000002 and CB_Backwards
#         return result
#     V_20000000004 = AND_3(V_20000000002, CB_Backwards)
#
#     def AND_4(V_20000000005, V_20000000006):
#         result = Start and F4
#         return result
#     V_20000000007 = AND_4(Start, F4)
#
#     def OR_4(V_20000000004, V_20000000007):
#         result = V_20000000004 or V_20000000007
#         return result
#     V_20000000008 = OR_4(V_20000000004, V_20000000007)
#
#     def OR_5(V_30000000000, V_30000000001):
#         result = F1 or A2
#         return result
#     V_30000000002 = OR_5(F1, A2)
#
#     def OR_6(V_30000000003, V_30000000004):
#         result = RGB_Forwards01 or RGB_Forwards02
#         return result
#     V_30000000005 = OR_6(RGB_Forwards01, RGB_Forwards02)
#
#     def AND_5(V_30000000002, V_30000000005):
#         result = V_30000000002 and V_30000000005
#         return result
#     V_30000000006 = AND_5(V_30000000002, V_30000000005)
#
#     def AND_6(V_30000000007, V_30000000008):
#         result = Start and F4
#         return result
#     V_30000000009 = AND_6(Start, F4)
#
#     def AND_7(V_30000000010, V_30000000011):
#         result = A6 and Init_RGB_Forwards
#         return result
#     V_30000000012 = AND_7(A6, Init_RGB_Forwards)
#
#     def OR_7(V_30000000006, V_30000000009, V_30000000012):
#         result = V_30000000006 or V_30000000009 or V_30000000012
#         return result
#     V_30000000013 = OR_7(V_30000000006, V_30000000009, V_30000000012)
#
#     def OR_8(V_40000000000, V_40000000001):
#         result = F1 or A2
#         return result
#     V_40000000002 = OR_8(F1, A2)
#
#     def OR_9(V_40000000003, V_40000000004):
#         result = RGB_Backwards01 or RGB_Backwards02
#         return result
#     V_40000000005 = OR_9(RGB_Backwards01, RGB_Backwards02)
#
#     def AND_8(V_40000000002, V_40000000005):
#         result = V_40000000002 and V_40000000005
#         return result
#     V_40000000006 = AND_8(V_40000000002, V_40000000005)
#
#     def AND_9(V_40000000007, V_40000000008):
#         result = Start and F4
#         return result
#     V_40000000009 = AND_9(Start, F4)
#
#     def AND_10(V_40000000010, V_40000000011):
#         result = A6 and Init_RGB_Backwards
#         return result
#     V_40000000012 = AND_10(A6, Init_RGB_Backwards)
#
#     def OR_10(V_40000000006, V_40000000009, V_40000000012):
#         result = V_40000000006 or V_40000000009 or V_40000000012
#         return result
#     V_40000000013 = OR_10(V_40000000006, V_40000000009, V_40000000012)
#
#     def OR_11(V_50000000000, V_50000000001):
#         result = F1 or A2
#         return result
#     V_50000000002 = OR_11(F1, A2)
#
#     def OR_12(V_50000000003, V_50000000004):
#         result = RGB_VertikalDown01 or RGB_VertikalDown02
#         return result
#     V_50000000005 = OR_12(RGB_VertikalDown01, RGB_VertikalDown02)
#
#     def AND_11(V_50000000002, V_50000000005):
#         result = V_50000000002 and V_50000000005
#         return result
#     V_50000000006 = AND_11(V_50000000002, V_50000000005)
#
#     def AND_12(V_50000000007, V_50000000008):
#         result = Start and F4
#         return result
#     V_50000000009 = AND_12(Start, F4)
#
#     def AND_13(V_50000000010, V_50000000011):
#         result = A6 and Init_RGB_VertikalDown
#         return result
#     V_50000000012 = AND_13(A6, Init_RGB_VertikalDown)
#
#     def OR_13(V_50000000006, V_50000000009, V_50000000012):
#         result = V_50000000006 or V_50000000009 or V_50000000012
#         return result
#     V_50000000013 = OR_13(V_50000000006, V_50000000009, V_50000000012)
#
#     def OR_14(V_60000000000, V_60000000001):
#         result = F1 or A2
#         return result
#     V_60000000002 = OR_14(F1, A2)
#
#     def OR_15(V_60000000003, V_60000000004):
#         result = RGB_VertikalUp01 or RGB_VertikalUp02
#         return result
#     V_60000000005 = OR_15(RGB_VertikalUp01, RGB_VertikalUp02)
#
#     def AND_14(V_60000000002, V_60000000005):
#         result = V_60000000002 and V_60000000005
#         return result
#     V_60000000006 = AND_14(V_60000000002, V_60000000005)
#
#     def AND_15(V_60000000007, V_60000000008):
#         result = Start and F4
#         return result
#     V_60000000009 = AND_15(Start, F4)
#
#     def AND_16(V_60000000010, V_60000000011):
#         result = A6 and Init_RGB_VertikalUp
#         return result
#     V_60000000012 = AND_16(A6, Init_RGB_VertikalUp)
#
#     def OR_16(V_60000000006, V_60000000009, V_60000000012):
#         result = V_60000000006 or V_60000000009 or V_60000000012
#         return result
#     V_60000000013 = OR_16(V_60000000006, V_60000000009, V_60000000012)
#
#     def OR_17(V_70000000000, V_70000000001):
#         result = F1 or A2
#         return result
#     V_70000000002 = OR_17(F1, A2)
#
#     def OR_18(V_70000000003, V_70000000004):
#         result = RGB_HorizontalForwards01 or RGB_HorizontalForwards01
#         return result
#     V_70000000005 = OR_18(RGB_HorizontalForwards01, RGB_HorizontalForwards01)
#
#     def AND_17(V_70000000002, V_70000000005):
#         result = V_70000000002 and V_70000000005
#         return result
#     V_70000000006 = AND_17(V_70000000002, V_70000000005)
#
#     def AND_18(V_70000000007, V_70000000008):
#         result = Start and F4
#         return result
#     V_70000000009 = AND_18(Start, F4)
#
#     def AND_19(V_70000000010, V_70000000011):
#         result = A6 and Init_RGB_HorizontalForwads
#         return result
#     V_70000000012 = AND_19(A6, Init_RGB_HorizontalForwads)
#
#     def OR_19(V_70000000006, V_70000000009, V_70000000012):
#         result = V_70000000006 or V_70000000009 or V_70000000012
#         return result
#     V_70000000013 = OR_19(V_70000000006, V_70000000009, V_70000000012)
#
#     def OR_20(V_80000000000, V_80000000001):
#         result = F1 or A2
#         return result
#     V_80000000002 = OR_20(F1, A2)
#
#     def OR_21(V_80000000003, V_80000000004):
#         result = RGB_HorizontalBackwards01 or RGB_HorizontalBackwards02
#         return result
#     V_80000000005 = OR_21(RGB_HorizontalBackwards01, RGB_HorizontalBackwards02)
#
#     def AND_20(V_80000000002, V_80000000005):
#         result = V_80000000002 and V_80000000005
#         return result
#     V_80000000006 = AND_20(V_80000000002, V_80000000005)
#
#     def AND_21(V_80000000007, V_80000000008):
#         result = Start and F4
#         return result
#     V_80000000009 = AND_21(Start, F4)
#
#     def AND_22(V_80000000010, V_80000000011):
#         result = A6 and Init_RGB_HorizontalBackwards
#         return result
#     V_80000000012 = AND_22(A6, Init_RGB_HorizontalBackwards)
#
#     def OR_22(V_80000000006, V_80000000009, V_80000000012):
#         result = V_80000000006 or V_80000000009 or V_80000000012
#         return result
#     V_80000000013 = OR_22(V_80000000006, V_80000000009, V_80000000012)
#     ConveyorBeltForward = V_10000000009
#     print('Value of ConveyorBeltForward:', ConveyorBeltForward)
#     ConveyorBeltBackward = V_20000000008
#     print('Value of ConveyorBeltBackward:', ConveyorBeltBackward)
#     RGB_Forwards = V_30000000013
#     print('Value of RGB_Forwards:', RGB_Forwards)
#     RGB_Backwards = V_40000000013
#     print('Value of RGB_Backwards:', RGB_Backwards)
#     RGB_VerticalDown = V_50000000013
#     print('Value of RGB_VerticalDown:', RGB_VerticalDown)
#     RGB_VerticalUp = V_60000000013
#     print('Value of RGB_VerticalUp:', RGB_VerticalUp)
#     RGB_HorizontalForward = V_70000000013
#     print('Value of RGB_HorizontalForward:', RGB_HorizontalForward)
#     RGB_HorizontalBackward = V_80000000013
#     print('Value of RGB_HorizontalBackward:', RGB_HorizontalBackward)
#     Light_Q1 = F1
#     print('Value of Light_Q1:', Light_Q1)
#     Light_Q2 = F4
#     print('Value of Light_Q2:', Light_Q2)
#     Light_Q3 = A1
#     print('Value of Light_Q3:', Light_Q3)
#     return {'ConveyorBeltForward': ConveyorBeltForward, 'ConveyorBeltBackward': ConveyorBeltBackward, 'RGB_Forwards': RGB_Forwards, 'RGB_Backwards': RGB_Backwards, 'RGB_VerticalDown': RGB_VerticalDown, 'RGB_VerticalUp': RGB_VerticalUp, 'RGB_HorizontalForward': RGB_HorizontalForward, 'RGB_HorizontalBackward': RGB_HorizontalBackward, 'Light_Q1': Light_Q1, 'Light_Q2': Light_Q2, 'Light_Q3': Light_Q3}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_OperatingModes
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_OperatingModes
# Code (?code):    import time
#
# def HRL_OperatingModes(Stop: bool, D2: bool, A5: bool, D3: bool, Alt_abort: bool, F1: int, Err_detected: int, Alt_found: bool, A2, D1, Diag_finished, A6, F4, Schalter, bFirstScan, FirstScanCount, V_50000000007, A1, Schrittkette_GS, V_60000000004, Reset, Start, RS_InitialState.Q1, Cycle_finished):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def OR_1(V_10000000002, V_10000000003):
#         result = D2 or A5
#         return result
#     V_10000000004 = OR_1(D2, A5)
#
#     def SR(V_10000000001, V_10000000004):
#         result = V_10000000004
#         return result
#     V_10000000005 = SR(Stop, V_10000000004)
#
#     def AND_1(V_20000000000, V_20000000001):
#         result = D3 and Alt_abort
#         return result
#     V_20000000002 = AND_1(D3, Alt_abort)
#
#     def AND_2(V_20000000003, V_20000000004):
#         result = F1 and Err_detected
#         return result
#     V_20000000005 = AND_2(F1, Err_detected)
#
#     def OR_2(V_20000000002, V_20000000005):
#         result = V_20000000002 or V_20000000005
#         return result
#     V_20000000006 = OR_2(V_20000000002, V_20000000005)
#
#     def AND_3(V_20000000007, V_20000000008):
#         result = D3 and Alt_abort
#         return result
#     V_20000000009 = AND_3(D3, Alt_abort)
#
#     def OR_3(V_20000000009, V_20000000010):
#         result = V_20000000009 or A5
#         return result
#     V_20000000011 = OR_3(V_20000000009, A5)
#
#     def RS_1(V_20000000006, V_20000000011):
#         result = V_20000000011
#         return result
#     V_20000000012 = RS_1(V_20000000006, V_20000000011)
#
#     def AND_4(V_30000000000, V_30000000001):
#         result = D2 and Alt_found
#         return result
#     V_30000000002 = AND_4(D2, Alt_found)
#
#     def AND_5(V_30000000004, V_30000000005):
#         result = D2 and Alt_found
#         return result
#     V_30000000006 = AND_5(D2, Alt_found)
#
#     def OR_4(V_30000000003, V_30000000006, V_30000000007):
#         result = A2 or V_30000000006 or D1
#         return result
#     V_30000000008 = OR_4(A2, V_30000000006, D1)
#
#     def RS_2(V_30000000002, V_30000000008):
#         result = V_30000000008
#         return result
#     V_30000000009 = RS_2(V_30000000002, V_30000000008)
#
#     def AND_6(V_40000000000, V_40000000001, V_40000000002):
#         result = D2 and Err_detected and Diag_finished
#         return result
#     V_40000000003 = AND_6(D2, Err_detected, Diag_finished)
#
#     def AND_7(V_40000000004, V_40000000005):
#         result = D1 and Stop
#         return result
#     V_40000000006 = AND_7(D1, Stop)
#
#     def OR_5(V_40000000003, V_40000000006):
#         result = V_40000000003 or V_40000000006
#         return result
#     V_40000000007 = OR_5(V_40000000003, V_40000000006)
#
#     def OR_6(V_40000000008, V_40000000009):
#         result = A6 or D1
#         return result
#     V_40000000010 = OR_6(A6, D1)
#
#     def RS_3(V_40000000007, V_40000000010):
#         result = V_40000000010
#         return result
#     V_40000000011 = RS_3(V_40000000007, V_40000000010)
#
#     def OR_7(V_50000000001, V_50000000002):
#         result = Stop or Schalter
#         return result
#     V_50000000003 = OR_7(Stop, Schalter)
#
#     def AND_8(V_50000000000, V_50000000003):
#         result = F4 and V_50000000003
#         return result
#     V_50000000004 = AND_8(F4, V_50000000003)
#
#     def EQ_1(V_50000000006, V_50000000007):
#         result = FirstScanCount == V_50000000007
#         return result
#     V_50000000008 = EQ_1(FirstScanCount, V_50000000007)
#
#     def OR_8(V_50000000005, V_50000000008, V_50000000009):
#         result = bFirstScan or V_50000000008 or A5
#         return result
#     V_50000000010 = OR_8(bFirstScan, V_50000000008, A5)
#
#     def EXECUTE_1(V_50000000010):
#         """EXECUTE block – original ST-Code:
# IF AlwaysTrue THEN
# 	// Code, der nur beim ersten Scan ausgeführt werden soll
#     // Zum Beispiel: Initialisierung von Parametern, Setzen von Startwerten etc.
#     MethodCall_InitStateDrive := TRUE;
# 	InputVar_InitStateDrive := TRUE;
# 	FirstScanCount := Count1  + Count2;
# 	//bFirstScan := FALSE; // Nach der Ausführung die Variable zurücksetzen
# END_IF;"""
#         result = V_50000000010
#         return result
#
#     def OR_9(V_50000000004, V_50000000011):
#         result = V_50000000004 or V_50000000011
#         return result
#     V_50000000012 = OR_9(V_50000000004, V_50000000011)
#
#     def OR_10(V_50000000013, V_50000000014):
#         result = A1 or D1
#         return result
#     V_50000000015 = OR_10(A1, D1)
#
#     def RS_4(V_50000000012, V_50000000015):
#         result = V_50000000015
#         return result
#     V_50000000016 = RS_4(V_50000000012, V_50000000015)
#
#     def EXECUTE_2(V_60000000001):
#         """EXECUTE block – original ST-Code:
# MethodCall_InitStateDrive := FALSE;
# InputVar_InitStateDrive := FALSE;"""
#         result = Schrittkette_GS
#         return result
#
#     def EQ_2(V_60000000003, V_60000000004):
#         result = FirstScanCount == V_60000000004
#         return result
#     V_60000000005 = EQ_2(FirstScanCount, V_60000000004)
#
#     def AND_9(V_60000000000, V_60000000002, V_60000000005):
#         result = A6 and V_60000000002 and V_60000000005
#         return result
#     V_60000000006 = AND_9(A6, V_60000000002, V_60000000005)
#
#     def EXECUTE_3(V_60000000008):
#         """EXECUTE block – original ST-Code:
# MethodCall_InitStateDrive := FALSE;
# InputVar_InitStateDrive := FALSE;"""
#         result = Schrittkette_GS
#         return result
#
#     def AND_10(V_60000000007, V_60000000009):
#         result = A2 and V_60000000009
#         return result
#     V_60000000010 = AND_10(A2, V_60000000009)
#
#     def OR_11(V_60000000006, V_60000000010):
#         result = V_60000000006 or V_60000000010
#         return result
#     V_60000000011 = OR_11(V_60000000006, V_60000000010)
#
#     def OR_12(V_60000000012, V_60000000013, V_60000000014):
#         result = F4 or F1 or D1
#         return result
#     V_60000000015 = OR_12(F4, F1, D1)
#
#     def RS_5(V_60000000011, V_60000000015):
#         result = V_60000000015
#         return result
#     V_60000000016 = RS_5(V_60000000011, V_60000000015)
#
#     def EXECUTE_4(V_60000000016):
#         """EXECUTE block – original ST-Code:
# FirstScanCount := 0;
# bFirstScan := FALSE;"""
#         result = V_60000000016
#         return result
#
#     def AND_11(V_70000000000, V_70000000001, V_70000000002):
#         result = Schalter and A1 and Reset
#         return result
#     V_70000000003 = AND_11(Schalter, A1, Reset)
#
#     def OR_13(V_70000000004, V_70000000005):
#         result = A6 or D1
#         return result
#     V_70000000006 = OR_13(A6, D1)
#
#     def RS_6(V_70000000003, V_70000000006):
#         result = V_70000000006
#         return result
#     V_70000000007 = RS_6(V_70000000003, V_70000000006)
#
#     def AND_12(V_80000000000, V_80000000001, V_80000000002):
#         result = Start and RS_InitialState.Q1 and Schalter
#         return result
#     V_80000000003 = AND_12(Start, RS_InitialState.Q1, Schalter)
#
#     def OR_14(V_80000000004, V_80000000005, V_80000000006, V_80000000007):
#         result = A2 or D1 or D2 or D3
#         return result
#     V_80000000008 = OR_14(A2, D1, D2, D3)
#
#     def RS_7(V_80000000003, V_80000000008):
#         result = V_80000000008
#         return result
#     V_80000000009 = RS_7(V_80000000003, V_80000000008)
#
#     def AND_13(V_90000000000, V_90000000001):
#         result = F1 and Cycle_finished
#         return result
#     V_90000000002 = AND_13(F1, Cycle_finished)
#
#     def OR_15(V_90000000003, V_90000000004):
#         result = A1 or D1
#         return result
#     V_90000000005 = OR_15(A1, D1)
#
#     def RS_8(V_90000000002, V_90000000005):
#         result = V_90000000005
#         return result
#     V_90000000006 = RS_8(V_90000000002, V_90000000005)
#     D1 = V_10000000005
#     print('Value of D1:', D1)
#     D2 = V_20000000012
#     print('Value of D2:', D2)
#     D3 = V_30000000009
#     print('Value of D3:', D3)
#     A5 = V_40000000011
#     print('Value of A5:', A5)
#     A6 = V_50000000016
#     print('Value of A6:', A6)
#     A1 = V_60000000017
#     print('Value of A1:', A1)
#     F4 = V_70000000007
#     print('Value of F4:', F4)
#     F1 = V_80000000009
#     print('Value of F1:', F1)
#     A2 = V_90000000006
#     print('Value of A2:', A2)
#     return {'D1': D1, 'D2': D2, 'D3': D3, 'A5': A5, 'A6': A6, 'A1': A1, 'F4': F4, 'F1': F1, 'A2': A2}
# ------------------------------
# Variable (?v):   http://www.semanticweb.org/AgentProgramParams/Var_HRL_SkillSet_HRL_RGB_InitialStateDrive
# Programm (?prog): http://www.semanticweb.org/AgentProgramParams/Program_HRL_RGB_InitialStateDrive
# Code (?code):    import time
#
# def HRL_RGB_InitialStateDrive(MethodCall_InitDrive: bool, ESS: bool, DirectionVerticalSRM: bool, InputInitDriveMode: bool, V_10000000005, TouchSensor01_SRM: bool, TSR: int, V_10000000008, TOF_Time_TSR, InitDriveMode, DirectionVertical, V_20000000004, TouchSensor02_RGB_vertical, V_20000000007, DirectionHorizontal, V_30000000004, TouchSensor03_RGB_horizontal, V_30000000007):
#     """Auto-generated from PLCopen XML (vereinfachte Semantik)."""
#
#     def AxisControl_MultipleInputSensors_1(V_10000000001, V_10000000002, V_10000000003, V_10000000004, V_10000000005, V_10000000006, V_10000000007, V_10000000008, V_10000000009, V_10000000010):
#         result = InitDriveMode
#         return result
#     V_10000000011 = AxisControl_MultipleInputSensors_1(MethodCall_InitDrive, ESS, DirectionVerticalSRM, InputInitDriveMode, V_10000000005, TouchSensor01_SRM, TSR, V_10000000008, TOF_Time_TSR, InitDriveMode)
#
#     def AxisControl_MultipleInputSensors_2(V_20000000000, V_20000000001, V_20000000002, V_20000000003, V_20000000004, V_20000000005, V_20000000006, V_20000000007, V_20000000008, V_20000000009):
#         result = InitDriveMode
#         return result
#     V_20000000010 = AxisControl_MultipleInputSensors_2(MethodCall_InitDrive, ESS, DirectionVertical, InputInitDriveMode, V_20000000004, TouchSensor02_RGB_vertical, TSR, V_20000000007, TOF_Time_TSR, InitDriveMode)
#
#     def AxisControl_MultipleInputSensors_3(V_30000000000, V_30000000001, V_30000000002, V_30000000003, V_30000000004, V_30000000005, V_30000000006, V_30000000007, V_30000000008, V_30000000009):
#         result = InitDriveMode
#         return result
#     V_30000000010 = AxisControl_MultipleInputSensors_3(MethodCall_InitDrive, ESS, DirectionHorizontal, InputInitDriveMode, V_30000000004, TouchSensor03_RGB_horizontal, TSR, V_30000000007, TOF_Time_TSR, InitDriveMode)
#     SRM_MotorBackwards = V_10000000011
#     print('Value of SRM_MotorBackwards:', SRM_MotorBackwards)
#     RGB_VerticalUp = V_20000000010
#     print('Value of RGB_VerticalUp:', RGB_VerticalUp)
#     RGB_HorizontalBackwards = V_30000000010
#     print('Value of RGB_HorizontalBackwards:', RGB_HorizontalBackwards)
#     return {'SRM_MotorBackwards': SRM_MotorBackwards, 'RGB_VerticalUp': RGB_VerticalUp, 'RGB_HorizontalBackwards': RGB_HorizontalBackwards}
# ------------------------------
#
# ### Ergebnisse als Pandas DataFrame ###
#                                                  prog  \
# 0   http://www.semanticweb.org/AgentProgramParams/...
# 1   http://www.semanticweb.org/AgentProgramParams/...
# 2   http://www.semanticweb.org/AgentProgramParams/...
# 3   http://www.semanticweb.org/AgentProgramParams/...
# 4   http://www.semanticweb.org/AgentProgramParams/...
# 5   http://www.semanticweb.org/AgentProgramParams/...
# 6   http://www.semanticweb.org/AgentProgramParams/...
# 7   http://www.semanticweb.org/AgentProgramParams/...
# 8   http://www.semanticweb.org/AgentProgramParams/...
# 9   http://www.semanticweb.org/AgentProgramParams/...
# 10  http://www.semanticweb.org/AgentProgramParams/...
#
#                                                     v  \
# 0   http://www.semanticweb.org/AgentProgramParams/...
# 1   http://www.semanticweb.org/AgentProgramParams/...
# 2   http://www.semanticweb.org/AgentProgramParams/...
# 3   http://www.semanticweb.org/AgentProgramParams/...
# 4   http://www.semanticweb.org/AgentProgramParams/...
# 5   http://www.semanticweb.org/AgentProgramParams/...
# 6   http://www.semanticweb.org/AgentProgramParams/...
# 7   http://www.semanticweb.org/AgentProgramParams/...
# 8   http://www.semanticweb.org/AgentProgramParams/...
# 9   http://www.semanticweb.org/AgentProgramParams/...
# 10  http://www.semanticweb.org/AgentProgramParams/...
#
#                                                  code
# 0   import time\n\ndef HRL_CB_AS_HorizontalMoveSen...
# 1   import time\n\ndef HRL_CB_AS_HorizontalMoveSen...
# 2   import time\n\ndef HRL_RGB_AS_HorizontalMoveSe...
# 3   import time\n\ndef HRL_RGB_AS_HorizontalMoveSe...
# 4   import time\n\ndef HRL_RGB_AS_VerticalMoveEnco...
# 5   import time\n\ndef HRL_RGB_AS_VerticalMoveEnco...
# 6   import time\n\ndef HRL_RGB_AS_HorizontalMoveEn...
# 7   import time\n\ndef HRL_RGB_AS_HorizontalMoveEn...
# 8   import time\n\ndef HRL_ControlOfOutputs(F1: bo...
# 9   import time\n\ndef HRL_OperatingModes(Stop: bo...
# 10  import time\n\ndef HRL_RGB_InitialStateDrive(M...

# %%
from rdflib import Graph, Namespace, RDF

g = Graph()
g.parse(r"D:\MA_Python_Agent\MSRGuard\KGs\Test_filled2.ttl", format='turtle')

AG = Namespace("http://www.semanticweb.org/AgentProgramParams/")

vars_ = set(g.subjects(RDF.type, AG.class_Variable))

prog_links = set()

for v in vars_:
    # alle Programmlinks einsammeln
    for p in g.subjects(AG.op_hasInputVariable, v):
        prog_links.add(v)
    for p in g.subjects(AG.op_hasOutputVariable, v):
        prog_links.add(v)
    for p in g.subjects(AG.op_hasInternVariable, v):
        prog_links.add(v)
    for p in g.subjects(AG.op_usesVariable, v):
        prog_links.add(v)
    for prog in g.objects(v, AG.op_isMappedToProgram):
        prog_links.add(v)

unlinked = [v for v in vars_ if v not in prog_links]

print("Anzahl Variablen:", len(vars_))
print("Davon ohne Programmlink:", len(unlinked))

for v in sorted(unlinked)[:20]:
    print(v.split("/")[-1])
# Out:
# Anzahl Variablen: 1491
# Davon ohne Programmlink: 333
# GVL_Diagnose__dot__Cycle_finished
# GVL_Diagnose__dot__Diag_finished
# GVL_Diagnose__dot__Err_detected
# GVL_HRL__dot__HRL_Enc_horizontal_I1
# GVL_HRL__dot__HRL_Enc_horizontal_I2
# GVL_HRL__dot__HRL_Enc_vertikal_I1
# GVL_HRL__dot__HRL_Enc_vertikal_I2
# GVL_HRL__dot__HRL_K1_1_Zaehler_Zuruecksetzen
# GVL_HRL__dot__HRL_K1_2_Zaehler_Zuruecksetzen
# GVL_HRL__dot__HRL_LS_aussen
# GVL_HRL__dot__HRL_LS_innen
# GVL_HRL__dot__HRL_MOT_Ausleger_rueckwaerts
# GVL_HRL__dot__HRL_MOT_Ausleger_vorwaerts
# GVL_HRL__dot__HRL_MOT_Foerderband_rueckwaerts
# GVL_HRL__dot__HRL_MOT_Foerderband_vorwaerts
# GVL_HRL__dot__HRL_MOT_horizontal_zum_Foerderband
# GVL_HRL__dot__HRL_MOT_horizontal_zum_Regal
# GVL_HRL__dot__HRL_MOT_vertikal_hoch
# GVL_HRL__dot__HRL_MOT_vertikal_runter
# GVL_HRL__dot__HRL_Ref_Taster_Ausleger_hinten
